# %% [markdown]
# ## Практикум 7. Задание.
#
# Используя библиотеки, pandas, requests, pyod:
# 1. Скачать, используя api.hh.ru, 500 вакансий, содержащих в названии "Разработчик", с указанием ЗП
# - 1.1 Оставить только id, name, area.name, salary.from, salary.to, salary.gross, salary.currency, employer.name
# 2. Используя средства pandas, сохранить эти вакансии в виде df.csv, df.json.
# 3. Создать пустые базы db1 и db2 в Sqlite3, c полями из 1.1
# 4. Наполнить базы, используя, соответственно считывание из csv и из json.
# 5. Создать пустую базу db3. Создать три таблицы - вакансии, города, и работодатели. Нормализовать таблицу из 1.1 и разбить ее данные на 3 перечисленные таблицы.
# 6. Средствами SQL создать новую колонку очищенной зарплаты в db3, содержащую
# среднюю зп по полям from и to, пересчитанную в рубли и очищенную от налога (для простоты - 13%)
# 7. По таблицам db3 с помощью JOIN, GROUP BY, HAVING, ORDER BY,
# вывести по убыванию очищенной зарплаты список вакансий в городах Москва и Ташкент
# 8. С помощью оконных функций (dense_rank) вывести в каждом городе вакансию с максимальной очищенной зп
# 9. С помощью оконных функций (lag, lead, next) для каждой вакансии вывести макс и мин очищенную зп

# %%
import pandas as pd
import requests
import sqlite3
import re
from typing import List, Dict

# %% [markdown]
# ####  1. Скачать, используя api.hh.ru, 500 вакансий, содержащих в названии "Разработчик", с указанием ЗП

# %%
url = "https://api.hh.ru/vacancies"

data = []
for i in range(5):
    params = {
        "text": "Разработчик",
        "area": 1,
        "per_page": 100,
        "page": i,
        "only_with_salary": True,
    }
    response = requests.get(url, params=params)
    data += response.json()["items"]

# %%
len(data)
# Out:
# 500

# %% [markdown]
# 1.1 Оставить только id, name, area.name, salary.from, salary.to, salary.gross, salary.currency, employer.name

# %%
df = pd.DataFrame(data)
df = df[["id", "name", "area", "salary", "snippet", "employer"]]
df["area_name"] = df["area"].apply(lambda x: x["name"])
df["salary_from"] = df["salary"].apply(lambda x: x["from"])
df["salary_to"] = df["salary"].apply(lambda x: x["to"])
df["salary_gross"] = df["salary"].apply(lambda x: x["gross"])
df["salary_currency"] = df["salary"].apply(lambda x: x["currency"])
df["employer_name"] = df["employer"].apply(lambda x: x["name"])
df = df[
    [
        "id",
        "name",
        "area_name",
        "salary_from",
        "salary_to",
        "salary_gross",
        "salary_currency",
        "employer_name",
    ]
]
df
# Out:
#             id                                              name area_name  \
# 0    112564663        Junior/Middle Frontend разработчик (React)    Москва
# 1    112763765  Junior front-end разработчик (TypeScript, React)    Москва
# 2    112783190                Инженер по охране окружающей среды    Москва
# 3    112746981                              Frontend-разработчик    Москва
# 4    112620411                                 Главный бухгалтер    Москва
# ..         ...                                               ...       ...
# 495  112294699        Senior Javascript / Typescript разработчик    Москва
# 496  112576157                           Программист станков ЧПУ    Москва
# 497  111089779                                SMM-менеджер (SMM)    Москва
# 498  111960819                        Frontend разработчик (Vue)    Москва
# 499  112445566                               Веб-дизайнер Middle    Москва
#
#      salary_from  salary_to  salary_gross salary_currency  \
# 0            NaN    70000.0         False             RUR
# 1       100000.0   180000.0         False             RUR
# 2       200000.0        NaN         False             RUR
# 3        70000.0        NaN         False             RUR
# 4       350000.0   500000.0         False             RUR
# ..           ...        ...           ...             ...
# 495     300000.0   400000.0         False             RUR
# 496     200000.0        NaN         False             RUR
# 497     150000.0        NaN         False             RUR
# 498     160000.0        NaN         False             RUR
# 499        600.0        NaN         False             USD
#
#                    employer_name
# 0                 Hammer Systems
# 1                        Mindbox
# 2               LOTS.Development
# 3                      Aiti Guru
# 4              ФАЙВ ЛЕМОНС ГРУПП
# ..                           ...
# 495                      Айкрафт
# 496  Центр Электронной Коммерции
# 497                       BYTIME
# 498                         Комс
# 499                          Мст
#
# [500 rows x 8 columns]

# %% [markdown]
# #### 2. Используя средства pandas, сохранить эти вакансии в виде df.csv, df.json.

# %%
df.to_csv("data/df.csv", index=False)
df.to_json("data/df.json", orient="records", lines=True)

# %% [markdown]
# #### 3. Создать пустые базы db1 и db2 в Sqlite3, c полями из 1.1

# %%
# Create db1
conn1 = sqlite3.connect("data/db1.sqlite")
c1 = conn1.cursor()
c1.execute(f"DROP TABLE IF EXISTS vacancies")
c1.execute("""
CREATE TABLE vacancies (
    id TEXT,
    name TEXT,
    area_name TEXT,
    salary_from REAL,
    salary_to REAL,
    salary_gross BOOLEAN,
    salary_currency TEXT,
    employer_name TEXT
)
""")
conn1.commit()
conn1.close()

# Create db2
conn2 = sqlite3.connect("data/db2.sqlite")
c2 = conn2.cursor()
c2.execute(f"DROP TABLE IF EXISTS vacancies")
c2.execute("""
CREATE TABLE vacancies (
    id TEXT,
    name TEXT,
    area_name TEXT,
    salary_from REAL,
    salary_to REAL,
    salary_gross BOOLEAN,
    salary_currency TEXT,
    employer_name TEXT
)
""")
conn2.commit()
conn2.close()

# %% [markdown]
# #### 4. Наполнить базы, используя, соответственно считывание из csv и из json.

# %%
def convert_types(data: List) -> List:
    output = []
    for raw_item in data:
        if raw_item.lower() in ["true", "false"]:
            output.append(raw_item.lower() == "true")
        elif raw_item.lower() == "null" or raw_item == "":
            output.append(None)
        else:
            try:
                if "." in raw_item:
                    output.append(float(raw_item))
                else:
                    output.append(int(raw_item))
            except ValueError:
                output.append(raw_item)
    return output

# %%
def find_all_indices(main_str: str, sub_str: str) -> List:
    indices = []
    start = main_str.find(sub_str)
    while start != -1:
        indices.append(start)
        start += len(sub_str)
        start = main_str.find(sub_str, start)
    return indices


def parse_line(line: str, sep: str = ",", quotechar: str = '"') -> List:
    quotes = find_all_indices(line, quotechar)
    i = 0
    while len(quotes) > i + 1:
        if quotes[i + 1] - quotes[i] == 1:
            quotes.pop(i)
            quotes.pop(i)
        else:
            i += 1

    if not quotes:
        return convert_types(line.split(sep=sep))
    else:
        if len(quotes) % 2 != 0:
            raise ValueError("Invalid quoting.")
        output = []
        quote_data = [line[: quotes[0]]]
        quote_data += [
            line[quotes[i] : quotes[i + 1] + 1] for i in range(0, len(quotes) - 1, 1)
        ]
        quote_data += [line[quotes[-1] + 1 :]]
        quote = False
        for data in quote_data:
            if quote:
                output.append(data[1:-1])
            elif data:
                raw_data = data
                if raw_data[0] == "," and not line.startswith(raw_data):
                    raw_data = raw_data[1:]
                if raw_data[-1] == "," and not line.endswith(raw_data):
                    raw_data = raw_data[:-1]

                output += convert_types(raw_data.split(sep=sep))
            quote = not quote
        return [item for item in output if item not in ["", '"']]


def csv_to_sql(
    db_path: str,
    csv_path: str,
    table_name: str,
    drop_if_exist: bool = False,
    sep: str = ",",
):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()

    if drop_if_exist:
        cursor.execute(f"DROP TABLE IF EXISTS {table_name}")

    with open(csv_path, "r", encoding="utf-8") as csv_file:
        headers = csv_file.readline().split(sep=sep)

        cursor.execute(
            f"CREATE TABLE IF NOT EXISTS {table_name} ({', '.join(headers)})"
        )

        # Insert the data into the table
        for row in csv_file:
            row = row[:-1]
            data = parse_line(row, sep=sep)
            placeholders = ", ".join(["?"] * len(data))
            cursor.execute(f"INSERT INTO {table_name} VALUES ({placeholders})", data)

    conn.commit()
    conn.close()

# %%
csv_to_sql("data/db1.sqlite", "data/df.csv", "vacancies", drop_if_exist=True)
# Out:
# 112564663,Junior/Middle Frontend разработчик (React),Москва,,70000.0,False,RUR,Hammer Systems
# [112564663, 'Junior/Middle Frontend разработчик (React)', 'Москва', None, 70000.0, False, 'RUR', 'Hammer Systems']
# 112763765,"Junior front-end разработчик (TypeScript, React)",Москва,100000.0,180000.0,False,RUR,Mindbox
# [112763765, 'Junior front-end разработчик (TypeScript, React)', 'Москва', 100000.0, 180000.0, False, 'RUR', 'Mindbox']
# 112783190,Инженер по охране окружающей среды,Москва,200000.0,,False,RUR,LOTS.Development
# [112783190, 'Инженер по охране окружающей среды', 'Москва', 200000.0, None, False, 'RUR', 'LOTS.Development']
# 112746981,Frontend-разработчик,Москва,70000.0,,False,RUR,Aiti Guru
# [112746981, 'Frontend-разработчик', 'Москва', 70000.0, None, False, 'RUR', 'Aiti Guru']
# 112620411,Главный бухгалтер,Москва,350000.0,500000.0,False,RUR,ФАЙВ ЛЕМОНС ГРУПП
# [112620411, 'Главный бухгалтер', 'Москва', 350000.0, 500000.0, False, 'RUR', 'ФАЙВ ЛЕМОНС ГРУПП']
# 111747905,Специалист контакт-центра,Москва,,80000.0,True,RUR,ПЕТЕР-СЕРВИС Спецтехнологии
# [111747905, 'Специалист контакт-центра', 'Москва', None, 80000.0, True, 'RUR', 'ПЕТЕР-СЕРВИС Спецтехнологии']
# 112690973,Python-разработчик (Junior),Москва,100000.0,120000.0,False,RUR,Альянс
# [112690973, 'Python-разработчик (Junior)', 'Москва', 100000.0, 120000.0, False, 'RUR', 'Альянс']
# 111784182,Frontend-разработчик,Москва,140000.0,,False,RUR,Милет Фэшн Групп
# [111784182, 'Frontend-разработчик', 'Москва', 140000.0, None, False, 'RUR', 'Милет Фэшн Групп']
# 112489402,Главный бухгалтер,Москва,250000.0,270000.0,False,RUR,Профсейф
# [112489402, 'Главный бухгалтер', 'Москва', 250000.0, 270000.0, False, 'RUR', 'Профсейф']
# 112695976,QA Engineer,Москва,1500.0,3300.0,True,EUR,HR Prime
# [112695976, 'QA Engineer', 'Москва', 1500.0, 3300.0, True, 'EUR', 'HR Prime']
# 112784445,Тестировщик ПО,Москва,90000.0,140000.0,False,RUR,Сфера
# [112784445, 'Тестировщик ПО', 'Москва', 90000.0, 140000.0, False, 'RUR', 'Сфера']
# 112545185,Младший тестировщик (Junior QA),Москва,90000.0,110000.0,False,RUR,Альянс
# [112545185, 'Младший тестировщик (Junior QA)', 'Москва', 90000.0, 110000.0, False, 'RUR', 'Альянс']
# 112089341,Руководитель отдела маркетинга и рекламы,Москва,200000.0,300000.0,False,RUR,САМОЛЕТ КОНСАЛТИНГ
# [112089341, 'Руководитель отдела маркетинга и рекламы', 'Москва', 200000.0, 300000.0, False, 'RUR', 'САМОЛЕТ КОНСАЛТИНГ']
# 111312670,Личный помощник руководителя/личный ассистент,Москва,200000.0,200000.0,False,RUR,MAAR DEVELOPMENT
# [111312670, 'Личный помощник руководителя/личный ассистент', 'Москва', 200000.0, 200000.0, False, 'RUR', 'MAAR DEVELOPMENT']
# 112777719,Программист станков с ЧПУ,Москва,300000.0,,True,RUR,НИИКАМ
# [112777719, 'Программист станков с ЧПУ', 'Москва', 300000.0, None, True, 'RUR', 'НИИКАМ']
# 112760179,Разработчик Python,Москва,100000.0,200000.0,False,RUR,Восхождение
# [112760179, 'Разработчик Python', 'Москва', 100000.0, 200000.0, False, 'RUR', 'Восхождение']
# 112440990,Руководитель проектов,Москва,450000.0,,False,RUR,WWAVE SPACE
# [112440990, 'Руководитель проектов', 'Москва', 450000.0, None, False, 'RUR', 'WWAVE SPACE']
# 112793387,Младший Тестировщик ПО,Москва,55000.0,55000.0,True,RUR,БИФИТ
# [112793387, 'Младший Тестировщик ПО', 'Москва', 55000.0, 55000.0, True, 'RUR', 'БИФИТ']
# 112494402,Стажер - программист,Москва,60000.0,60000.0,True,RUR,Copperside
# [112494402, 'Стажер - программист', 'Москва', 60000.0, 60000.0, True, 'RUR', 'Copperside']
# 112750238,"Frontend-разработчик (React.js, TypeScript) Middle+/Senior",Москва,,260000.0,False,RUR,Российское общество Знание
# [112750238, 'Frontend-разработчик (React.js, TypeScript) Middle+/Senior', 'Москва', None, 260000.0, False, 'RUR', 'Российское общество Знание']
# 112480285,"Junior+ Python разработчик, удаленно",Москва,60000.0,80000.0,False,RUR,е.Ком
# [112480285, 'Junior+ Python разработчик, удаленно', 'Москва', 60000.0, 80000.0, False, 'RUR', 'е.Ком']
# 111351666,Junior Backend Developer (Python),Москва,70000.0,,False,RUR,Effective Mobile
# [111351666, 'Junior Backend Developer (Python)', 'Москва', 70000.0, None, False, 'RUR', 'Effective Mobile']
# 111856035,"Системный администратор (1, 2 линия)",Москва,90000.0,110000.0,False,RUR,Лаборатория Наносемантика
# [111856035, 'Системный администратор (1, 2 линия)', 'Москва', 90000.0, 110000.0, False, 'RUR', 'Лаборатория Наносемантика']
# 111607593,Бизнес-аналитик,Москва,200000.0,,False,RUR,Topface
# [111607593, 'Бизнес-аналитик', 'Москва', 200000.0, None, False, 'RUR', 'Topface']
# 112522800,Customer Support Agent,Москва,80000.0,,False,RUR,СКВИЛЛА
# [112522800, 'Customer Support Agent', 'Москва', 80000.0, None, False, 'RUR', 'СКВИЛЛА']
# 112590016,Специалист по документообороту,Москва,110000.0,110000.0,True,RUR,Главстрой (Москва)
# [112590016, 'Специалист по документообороту', 'Москва', 110000.0, 110000.0, True, 'RUR', 'Главстрой (Москва)']
# 112698776,Unity Developer (Junior+). Разработчик игр на Unity,Москва,200.0,,False,USD,GeeKid
# [112698776, 'Unity Developer (Junior+). Разработчик игр на Unity', 'Москва', 200.0, None, False, 'USD', 'GeeKid']
# 112615359,Python разработчик,Москва,180000.0,350000.0,False,RUR,AlfaBit
# [112615359, 'Python разработчик', 'Москва', 180000.0, 350000.0, False, 'RUR', 'AlfaBit']
# 112790802,Руководитель департамента Бизнес анализа,Москва,,500000.0,False,RUR,Work&Wolf
# [112790802, 'Руководитель департамента Бизнес анализа', 'Москва', None, 500000.0, False, 'RUR', 'Work&Wolf']
# 111345990,Начинающий программист (junior),Москва,70000.0,130000.0,True,RUR,Омега
# [111345990, 'Начинающий программист (junior)', 'Москва', 70000.0, 130000.0, True, 'RUR', 'Омега']
# 112771151,Python-разработчик,Москва,,230000.0,False,RUR,KTS
# [112771151, 'Python-разработчик', 'Москва', None, 230000.0, False, 'RUR', 'KTS']
# 112792214,Frontend-разработчик,Москва,200000.0,,True,RUR,ART 3D-Graphics
# [112792214, 'Frontend-разработчик', 'Москва', 200000.0, None, True, 'RUR', 'ART 3D-Graphics']
# 112627301,Персональный ассистент,Москва,200000.0,,False,RUR,Orion Solutions
# [112627301, 'Персональный ассистент', 'Москва', 200000.0, None, False, 'RUR', 'Orion Solutions']
# 111349601,Junior GO Developer,Москва,70000.0,,False,RUR,Effective Mobile
# [111349601, 'Junior GO Developer', 'Москва', 70000.0, None, False, 'RUR', 'Effective Mobile']
# 110802210,QA manual / QA engineer,Москва,120000.0,150000.0,True,RUR,Феникс
# [110802210, 'QA manual / QA engineer', 'Москва', 120000.0, 150000.0, True, 'RUR', 'Феникс']
# 112510123,Главный бухгалтер,Москва,,250000.0,False,RUR,Мария Репина Юрьевна
# [112510123, 'Главный бухгалтер', 'Москва', None, 250000.0, False, 'RUR', 'Мария Репина Юрьевна']
# 110952392,Руководитель отдела по развитию бизнеса,Москва,,500000.0,False,RUR,Brainics
# [110952392, 'Руководитель отдела по развитию бизнеса', 'Москва', None, 500000.0, False, 'RUR', 'Brainics']
# 112051210,"Тестировщик (бэк, ручное тестирование)",Москва,80000.0,90000.0,False,RUR,KONNEKTU
# [112051210, 'Тестировщик (бэк, ручное тестирование)', 'Москва', 80000.0, 90000.0, False, 'RUR', 'KONNEKTU']
# 112057928,Entry-level specialist with knowledge of English (Moscow),Москва,1000.0,2000.0,False,USD,Индгроз Сервис
# [112057928, 'Entry-level specialist with knowledge of English (Moscow)', 'Москва', 1000.0, 2000.0, False, 'USD', 'Индгроз Сервис']
# 112761759,QA Engineer,Москва,80000.0,100000.0,False,RUR,Перспектива
# [112761759, 'QA Engineer', 'Москва', 80000.0, 100000.0, False, 'RUR', 'Перспектива']
# 110113881,Бизнес-аналитик,Москва,120000.0,,False,RUR,СДС
# [110113881, 'Бизнес-аналитик', 'Москва', 120000.0, None, False, 'RUR', 'СДС']
# 110286826,Intern Data Analyst / Стажер - аналитик данных,Москва,100000.0,,True,RUR,Procter & Gamble
# [110286826, 'Intern Data Analyst / Стажер - аналитик данных', 'Москва', 100000.0, None, True, 'RUR', 'Procter & Gamble']
# 112042389,Менеджер по поддержке клиентов (удалённо),Москва,1200.0,,False,EUR,Wapi OÜ
# [112042389, 'Менеджер по поддержке клиентов (удалённо)', 'Москва', 1200.0, None, False, 'EUR', 'Wapi OÜ']
# 112344023,Junior Golang-разработчик,Москва,100000.0,160000.0,False,RUR,RecruitTech
# [112344023, 'Junior Golang-разработчик', 'Москва', 100000.0, 160000.0, False, 'RUR', 'RecruitTech']
# 112551373,Middle-Frontend разработчик,Москва,180000.0,220000.0,False,RUR,Спортифаиндер
# [112551373, 'Middle-Frontend разработчик', 'Москва', 180000.0, 220000.0, False, 'RUR', 'Спортифаиндер']
# 112762856,Android (Kotlin) разработчик,Москва,100000.0,200000.0,False,RUR,Восхождение
# [112762856, 'Android (Kotlin) разработчик', 'Москва', 100000.0, 200000.0, False, 'RUR', 'Восхождение']
# 112773669,Head of PR,Москва,300000.0,,False,RUR,Lenkep recruitment
# [112773669, 'Head of PR', 'Москва', 300000.0, None, False, 'RUR', 'Lenkep recruitment']
# 112494667,Главный бухгалтер в группу компаний,Москва,200000.0,260000.0,False,RUR,Media 108
# [112494667, 'Главный бухгалтер в группу компаний', 'Москва', 200000.0, 260000.0, False, 'RUR', 'Media 108']
# 111349843,Копирайтер,Москва,70000.0,,False,RUR,Comindware
# [111349843, 'Копирайтер', 'Москва', 70000.0, None, False, 'RUR', 'Comindware']
# 112771250,Программист Java (backend),Москва,180000.0,230000.0,False,RUR,Кадровое агентство Аспект
# [112771250, 'Программист Java (backend)', 'Москва', 180000.0, 230000.0, False, 'RUR', 'Кадровое агентство Аспект']
# 111059850,Junior QA Engineer (тестировщик),Москва,,100000.0,False,RUR,Альбато
# [111059850, 'Junior QA Engineer (тестировщик)', 'Москва', None, 100000.0, False, 'RUR', 'Альбато']
# 111198545,Специалист по тестированию,Москва,110000.0,,False,RUR,Уникальные Волоконные Приборы - Комплексные Системы
# [111198545, 'Специалист по тестированию', 'Москва', 110000.0, None, False, 'RUR', 'Уникальные Волоконные Приборы - Комплексные Системы']
# 111628143,Python-разработчик,Москва,,240000.0,False,RUR,Антара
# [111628143, 'Python-разработчик', 'Москва', None, 240000.0, False, 'RUR', 'Антара']
# 112355107,Программист-разработчик (Junior),Москва,30000.0,,False,RUR,Группа компаний «БПО»
# [112355107, 'Программист-разработчик (Junior)', 'Москва', 30000.0, None, False, 'RUR', 'Группа компаний «БПО»']
# 110868149,Менеджер по продажам В2В,Москва,80000.0,130000.0,False,RUR,Селлематикс
# [110868149, 'Менеджер по продажам В2В', 'Москва', 80000.0, 130000.0, False, 'RUR', 'Селлематикс']
# 112436992,Стажер DevOps-инженер,Москва,50000.0,,False,RUR,Эксайт Кит
# [112436992, 'Стажер DevOps-инженер', 'Москва', 50000.0, None, False, 'RUR', 'Эксайт Кит']
# 112630641,Backend-разработчик PHP (middle),Москва,140000.0,180000.0,False,RUR,РСК
# [112630641, 'Backend-разработчик PHP (middle)', 'Москва', 140000.0, 180000.0, False, 'RUR', 'РСК']
# 112537379,QA Тестировщик (desktop),Москва,80000.0,120000.0,False,RUR,КИТТ
# [112537379, 'QA Тестировщик (desktop)', 'Москва', 80000.0, 120000.0, False, 'RUR', 'КИТТ']
# 112778043,IT - Project manager,Москва,130000.0,,False,RUR,Сайбертех
# [112778043, 'IT - Project manager', 'Москва', 130000.0, None, False, 'RUR', 'Сайбертех']
# 112347786,Тестировщик QA,Москва,100000.0,,False,RUR,Сайбертех
# [112347786, 'Тестировщик QA', 'Москва', 100000.0, None, False, 'RUR', 'Сайбертех']
# 112738199,Android Developer,Москва,,550000.0,True,RUR,Offer Now
# [112738199, 'Android Developer', 'Москва', None, 550000.0, True, 'RUR', 'Offer Now']
# 112402476,Lead QA engineer (GitVerse),Москва,,450000.0,False,RUR,SberTech
# [112402476, 'Lead QA engineer (GitVerse)', 'Москва', None, 450000.0, False, 'RUR', 'SberTech']
# 112715391,3D-моделлер / 3D-визуализатор (на проект),Москва,,50000.0,False,RUR,ГРЕЧКА
# [112715391, '3D-моделлер / 3D-визуализатор (на проект)', 'Москва', None, 50000.0, False, 'RUR', 'ГРЕЧКА']
# 112760153,Android разработчик,Москва,100000.0,200000.0,False,RUR,Восхождение
# [112760153, 'Android разработчик', 'Москва', 100000.0, 200000.0, False, 'RUR', 'Восхождение']
# 111444669,Middle Manual QA Engineer,Москва,80000.0,150000.0,True,RUR,Бринго
# [111444669, 'Middle Manual QA Engineer', 'Москва', 80000.0, 150000.0, True, 'RUR', 'Бринго']
# 111220925,Ручной тестировщик,Москва,100000.0,,False,RUR,Альпина Паблишер
# [111220925, 'Ручной тестировщик', 'Москва', 100000.0, None, False, 'RUR', 'Альпина Паблишер']
# 112716353,"Специалист по маркировке ""Честный знак""",Москва,80000.0,,False,RUR,Роял Фрут Русь
# [112716353, 'Специалист по маркировке ""Честный знак""', 'Москва', 80000.0, None, False, 'RUR', 'Роял Фрут Русь']
# 111903222,Frontend-разработчик,Москва,120000.0,150000.0,False,RUR,ЛВ Софт
# [111903222, 'Frontend-разработчик', 'Москва', 120000.0, 150000.0, False, 'RUR', 'ЛВ Софт']
# 112696349,Senior Product Manager,Москва,290000.0,,False,RUR,BelkaCar
# [112696349, 'Senior Product Manager', 'Москва', 290000.0, None, False, 'RUR', 'BelkaCar']
# 110816369,"Инженер-программист отдела комплексной разработки, сопровождения и отладки специальных систем",Москва,100000.0,,False,RUR,"Моринформсистема-Агат, Концерн"
# [110816369, 'Инженер-программист отдела комплексной разработки, сопровождения и отладки специальных систем', 'Москва', 100000.0, None, False, 'RUR', 'Моринформсистема-Агат, Концерн']
# 110961770,Junior Java Developer,Москва,70000.0,,False,RUR,Effective Mobile
# [110961770, 'Junior Java Developer', 'Москва', 70000.0, None, False, 'RUR', 'Effective Mobile']
# 112368117,SEO-специалист (middle-senior),Москва,200000.0,350000.0,False,RUR,Лопатин Владимир Андреевич
# [112368117, 'SEO-специалист (middle-senior)', 'Москва', 200000.0, 350000.0, False, 'RUR', 'Лопатин Владимир Андреевич']
# 106289021,Специалист (в офис),Москва,200000.0,250000.0,False,RUR,Самолет Плюс Мск Юг
# [106289021, 'Специалист (в офис)', 'Москва', 200000.0, 250000.0, False, 'RUR', 'Самолет Плюс Мск Юг']
# 111274865,Junior Java-программист,Москва,60000.0,120000.0,False,RUR,Oxytocin
# [111274865, 'Junior Java-программист', 'Москва', 60000.0, 120000.0, False, 'RUR', 'Oxytocin']
# 112738273,Руководитель ИТ-проектов (Junior / Middle),Москва,175000.0,250000.0,True,RUR,BTLab
# [112738273, 'Руководитель ИТ-проектов (Junior / Middle)', 'Москва', 175000.0, 250000.0, True, 'RUR', 'BTLab']
# 106472891,Куратор студентов в Яндекс Практикум,Москва,50000.0,50000.0,False,RUR,Яндекс Практикум
# [106472891, 'Куратор студентов в Яндекс Практикум', 'Москва', 50000.0, 50000.0, False, 'RUR', 'Яндекс Практикум']
# 112436052,Младший тестировщик игр,Санкт-Петербург,80000.0,80000.0,True,RUR,Пиксель Шквал
# [112436052, 'Младший тестировщик игр', 'Санкт-Петербург', 80000.0, 80000.0, True, 'RUR', 'Пиксель Шквал']
# 110970217,Junior Java developer,Москва,80000.0,,False,RUR,Бюро кредитных историй Скоринг Бюро
# [110970217, 'Junior Java developer', 'Москва', 80000.0, None, False, 'RUR', 'Бюро кредитных историй Скоринг Бюро']
# 112716644,Разработчик Python,Москва,100000.0,140000.0,False,RUR,EORA
# [112716644, 'Разработчик Python', 'Москва', 100000.0, 140000.0, False, 'RUR', 'EORA']
# 111986443,Тестировщик ПО (manual),Москва,150000.0,250000.0,False,RUR,OONE WORLD
# [111986443, 'Тестировщик ПО (manual)', 'Москва', 150000.0, 250000.0, False, 'RUR', 'OONE WORLD']
# 112602893,Frontend developer (JavaScript),Москва,4000.0,,False,EUR,Топассистент
# [112602893, 'Frontend developer (JavaScript)', 'Москва', 4000.0, None, False, 'EUR', 'Топассистент']
# 110883330,Python разработчик (Django),Москва,50000.0,90000.0,False,RUR,Hammer Systems
# [110883330, 'Python разработчик (Django)', 'Москва', 50000.0, 90000.0, False, 'RUR', 'Hammer Systems']
# 112650455,Frontend Developer,Москва,3000.0,5000.0,True,USD,Podscribe
# [112650455, 'Frontend Developer', 'Москва', 3000.0, 5000.0, True, 'USD', 'Podscribe']
# 112612072,Java-разработчик,Москва,200000.0,250000.0,False,RUR,Прайм-Айти
# [112612072, 'Java-разработчик', 'Москва', 200000.0, 250000.0, False, 'RUR', 'Прайм-Айти']
# 112772438,Бэкенд-разработчик Python / Backend Python Developer (Middle),Москва,180000.0,220000.0,False,RUR,Группа компаний ТехноТранс (АО Технотранс)
# [112772438, 'Бэкенд-разработчик Python / Backend Python Developer (Middle)', 'Москва', 180000.0, 220000.0, False, 'RUR', 'Группа компаний ТехноТранс (АО Технотранс)']
# 111946301,Программист PHP,Москва,40000.0,65000.0,False,RUR,Фьюче
# [111946301, 'Программист PHP', 'Москва', 40000.0, 65000.0, False, 'RUR', 'Фьюче']
# 112594462,HTML-верстальщик,Москва,80000.0,130000.0,False,RUR,Semprogroup
# [112594462, 'HTML-верстальщик', 'Москва', 80000.0, 130000.0, False, 'RUR', 'Semprogroup']
# 112755714,Flutter разработчик,Москва,150000.0,350000.0,False,RUR,Слепая курица
# [112755714, 'Flutter разработчик', 'Москва', 150000.0, 350000.0, False, 'RUR', 'Слепая курица']
# 112787920,Junior game designer,Москва,,50000.0,False,RUR,Волеводз Дмитрий Александрович
# [112787920, 'Junior game designer', 'Москва', None, 50000.0, False, 'RUR', 'Волеводз Дмитрий Александрович']
# 112743163,Junior IT специалист | Системный аналитик,Москва,100000.0,160000.0,False,RUR,Soar high software
# [112743163, 'Junior IT специалист | Системный аналитик', 'Москва', 100000.0, 160000.0, False, 'RUR', 'Soar high software']
# 112650446,Lead Frontend Developer,Москва,5000.0,8000.0,True,USD,Podscribe
# [112650446, 'Lead Frontend Developer', 'Москва', 5000.0, 8000.0, True, 'USD', 'Podscribe']
# 112795264,Junior QA Инженер,Москва,75000.0,75000.0,False,RUR,FunFlow (ООО Мобильные Игровые Решения)
# [112795264, 'Junior QA Инженер', 'Москва', 75000.0, 75000.0, False, 'RUR', 'FunFlow (ООО Мобильные Игровые Решения)']
# 112443168,Хостес в ресторан Mela,Москва,100000.0,,False,RUR,Agalarov Development
# [112443168, 'Хостес в ресторан Mela', 'Москва', 100000.0, None, False, 'RUR', 'Agalarov Development']
# 112168396,Администратор сайта/Контент менеджер,Москва,70000.0,90000.0,False,RUR,Автохаус
# [112168396, 'Администратор сайта/Контент менеджер', 'Москва', 70000.0, 90000.0, False, 'RUR', 'Автохаус']
# 112607639,Project manager,Москва,280000.0,350000.0,False,RUR,PROFITEROLE
# [112607639, 'Project manager', 'Москва', 280000.0, 350000.0, False, 'RUR', 'PROFITEROLE']
# 112786679,PHP разработчик Laravel,Москва,1000.0,1500.0,True,USD,Alexarix
# [112786679, 'PHP разработчик Laravel', 'Москва', 1000.0, 1500.0, True, 'USD', 'Alexarix']
# 112449877,Администратор сайта,Москва,300000.0,350000.0,True,RUR,Мешков Роман Владимирович
# [112449877, 'Администратор сайта', 'Москва', 300000.0, 350000.0, True, 'RUR', 'Мешков Роман Владимирович']
# 109026369,Программист 1С (senior),Москва,237000.0,335000.0,False,RUR,EXPICO
# [109026369, 'Программист 1С (senior)', 'Москва', 237000.0, 335000.0, False, 'RUR', 'EXPICO']
# 112751586,PHP программист,Москва,120000.0,,False,RUR,Геномед
# [112751586, 'PHP программист', 'Москва', 120000.0, None, False, 'RUR', 'Геномед']
# 111261368,QA Engineer (Manual),Москва,3000.0,,True,USD,Коллектив Интеллидженс Системс
# [111261368, 'QA Engineer (Manual)', 'Москва', 3000.0, None, True, 'USD', 'Коллектив Интеллидженс Системс']
# 111807231,Тестировщик / QA Engineer (Middle) (Удаленно),Москва,2100.0,2300.0,False,USD,Superduper
# [111807231, 'Тестировщик / QA Engineer (Middle) (Удаленно)', 'Москва', 2100.0, 2300.0, False, 'USD', 'Superduper']
# 109571000,Секретарь в премиальную зону ресепшн,Москва,80000.0,100000.0,False,RUR,Bms Development Group
# [109571000, 'Секретарь в премиальную зону ресепшн', 'Москва', 80000.0, 100000.0, False, 'RUR', 'Bms Development Group']
# 112759781,Разработчик BIM,Москва,150000.0,,False,RUR,Брусника
# [112759781, 'Разработчик BIM', 'Москва', 150000.0, None, False, 'RUR', 'Брусника']
# 112537533,React developer,Москва,200000.0,,False,RUR,В Кадре
# [112537533, 'React developer', 'Москва', 200000.0, None, False, 'RUR', 'В Кадре']
# 111790740,"Продуктовый Дизайнер в hr, talent - tech стартап (международный)/Product Designer",Москва,100000.0,500000.0,False,RUR,Буров Алексей Константинович
# [111790740, 'Продуктовый Дизайнер в hr, talent - tech стартап (международный)/Product Designer', 'Москва', 100000.0, 500000.0, False, 'RUR', 'Буров Алексей Константинович']
# 112703532,UX/UI Designer,Москва,270000.0,,False,RUR,Spiel Media
# [112703532, 'UX/UI Designer', 'Москва', 270000.0, None, False, 'RUR', 'Spiel Media']
# 112352624,Специалист технической поддержки,Москва,80000.0,,False,RUR,IT-Доминанта
# [112352624, 'Специалист технической поддержки', 'Москва', 80000.0, None, False, 'RUR', 'IT-Доминанта']
# 112714482,Python-разработчик| Backend developer,Москва,100000.0,300000.0,False,RUR,Эквариум
# [112714482, 'Python-разработчик| Backend developer', 'Москва', 100000.0, 300000.0, False, 'RUR', 'Эквариум']
# 112042486,Бизнес-аналитик,Москва,,400000.0,False,RUR,БизнесМатика
# [112042486, 'Бизнес-аналитик', 'Москва', None, 400000.0, False, 'RUR', 'БизнесМатика']
# 111603555,Java-разработчик Middle (полностью удаленно),Москва,180000.0,250000.0,False,RUR,Фабрика Решений
# [111603555, 'Java-разработчик Middle (полностью удаленно)', 'Москва', 180000.0, 250000.0, False, 'RUR', 'Фабрика Решений']
# 112698189,Junior Project-менеджер,Москва,,120000.0,True,RUR,KTS
# [112698189, 'Junior Project-менеджер', 'Москва', None, 120000.0, True, 'RUR', 'KTS']
# 112174751,Junior QA Engineer,Москва,,100000.0,False,RUR,Перформикс
# [112174751, 'Junior QA Engineer', 'Москва', None, 100000.0, False, 'RUR', 'Перформикс']
# 112281223,ML engineer (middle-senior),Москва,500000.0,700000.0,False,RUR,Лопатин Владимир Андреевич
# [112281223, 'ML engineer (middle-senior)', 'Москва', 500000.0, 700000.0, False, 'RUR', 'Лопатин Владимир Андреевич']
# 112725665,Веб-программист,Москва,53000.0,155000.0,False,RUR,Cetera
# [112725665, 'Веб-программист', 'Москва', 53000.0, 155000.0, False, 'RUR', 'Cetera']
# 108637623,Frontend-разработчик,Москва,,150000.0,False,RUR,RecruitTech
# [108637623, 'Frontend-разработчик', 'Москва', None, 150000.0, False, 'RUR', 'RecruitTech']
# 112551325,Коммерческий директор (CCO),Москва,300000.0,,True,RUR,Романов Дмитрий Алексеевич
# [112551325, 'Коммерческий директор (CCO)', 'Москва', 300000.0, None, True, 'RUR', 'Романов Дмитрий Алексеевич']
# 111749326,Фронтенд-разработчик,Москва,200000.0,,True,RUR,ФГБУ ГИВЦ Минкультуры России
# [111749326, 'Фронтенд-разработчик', 'Москва', 200000.0, None, True, 'RUR', 'ФГБУ ГИВЦ Минкультуры России']
# 112039191,QA engineer / тестировщик (middle),Москва,100000.0,,False,RUR,Туроператор Русь
# [112039191, 'QA engineer / тестировщик (middle)', 'Москва', 100000.0, None, False, 'RUR', 'Туроператор Русь']
# 112762515,Инженер службы технической поддержки,Москва,80000.0,,True,RUR,Seeneco
# [112762515, 'Инженер службы технической поддержки', 'Москва', 80000.0, None, True, 'RUR', 'Seeneco']
# 112732617,Technical Service Engineer,Москва,4000.0,7000.0,False,USD,Lamipak
# [112732617, 'Technical Service Engineer', 'Москва', 4000.0, 7000.0, False, 'USD', 'Lamipak']
# 111114998,Инженер по тестированию ПО,Москва,250000.0,,False,RUR,ET HR
# [111114998, 'Инженер по тестированию ПО', 'Москва', 250000.0, None, False, 'RUR', 'ET HR']
# 112342343,Инженер по пожарной безопасности,Москва,200000.0,,False,RUR,LOTS.Development
# [112342343, 'Инженер по пожарной безопасности', 'Москва', 200000.0, None, False, 'RUR', 'LOTS.Development']
# 111090589,Руководитель отдела по работе с партнерами,Москва,300000.0,,False,RUR,BYTIME
# [111090589, 'Руководитель отдела по работе с партнерами', 'Москва', 300000.0, None, False, 'RUR', 'BYTIME']
# 106563411,Инженер по тестированию (продукт «Единый клиент»),Москва,,150000.0,False,RUR,HFLabs
# [106563411, 'Инженер по тестированию (продукт «Единый клиент»)', 'Москва', None, 150000.0, False, 'RUR', 'HFLabs']
# 112367720,"Менеджер по продажам (квалификация, регистрация)",Москва,90000.0,150000.0,False,RUR,GreenGo
# [112367720, 'Менеджер по продажам (квалификация, регистрация)', 'Москва', 90000.0, 150000.0, False, 'RUR', 'GreenGo']
# 112742953,UX/UI-дизайнер,Москва,150000.0,200000.0,True,RUR,АВТОДОК (Autodoc)
# [112742953, 'UX/UI-дизайнер', 'Москва', 150000.0, 200000.0, True, 'RUR', 'АВТОДОК (Autodoc)']
# 110578187,Junior Golang разработчик,Москва,50000.0,,False,RUR,Судоргин Артем
# [110578187, 'Junior Golang разработчик', 'Москва', 50000.0, None, False, 'RUR', 'Судоргин Артем']
# 112763600,Руководитель отдела персонала,Москва,170000.0,,True,RUR,Медиум
# [112763600, 'Руководитель отдела персонала', 'Москва', 170000.0, None, True, 'RUR', 'Медиум']
# 112449354,Офис-менеджер,Москва,,100000.0,False,RUR,Agalarov Development
# [112449354, 'Офис-менеджер', 'Москва', None, 100000.0, False, 'RUR', 'Agalarov Development']
# 112579976,Специалист технической поддержки (платежный шлюз),Москва,,150000.0,False,RUR,Monnect
# [112579976, 'Специалист технической поддержки (платежный шлюз)', 'Москва', None, 150000.0, False, 'RUR', 'Monnect']
# 111742838,Инженер-программист станков с ЧПУ,Москва,,350000.0,True,RUR,НЬЮТОН-ИТМ
# [111742838, 'Инженер-программист станков с ЧПУ', 'Москва', None, 350000.0, True, 'RUR', 'НЬЮТОН-ИТМ']
# 112162117,UX/UI-дизайнер IT-интерфейсов,Зеленоград,150000.0,,True,RUR,Промис Лаб
# [112162117, 'UX/UI-дизайнер IT-интерфейсов', 'Зеленоград', 150000.0, None, True, 'RUR', 'Промис Лаб']
# 111986458,Инженер-программист junior,Москва,110000.0,,True,RUR,ИНИТИ
# [111986458, 'Инженер-программист junior', 'Москва', 110000.0, None, True, 'RUR', 'ИНИТИ']
# 112408671,Frontend-разработчик React,Москва,,60000.0,False,RUR,ГРЕЧКА
# [112408671, 'Frontend-разработчик React', 'Москва', None, 60000.0, False, 'RUR', 'ГРЕЧКА']
# 112518117,Художник 2D-арта,Москва,80000.0,,True,RUR,Золотой Дракон
# [112518117, 'Художник 2D-арта', 'Москва', 80000.0, None, True, 'RUR', 'Золотой Дракон']
# 111939254,TeamLead / TeachLead Руководитель отдела разработки,Москва,500000.0,1500000.0,False,RUR,VPNM (Тихонов Денис Олегович)
# [111939254, 'TeamLead / TeachLead Руководитель отдела разработки', 'Москва', 500000.0, 1500000.0, False, 'RUR', 'VPNM (Тихонов Денис Олегович)']
# 112699734,Backend python developer,Москва,130000.0,,False,RUR,ПромоДата
# [112699734, 'Backend python developer', 'Москва', 130000.0, None, False, 'RUR', 'ПромоДата']
# 111181003,Специалист в офис,Москва,200000.0,250000.0,False,RUR,Самолет Плюс Мск Юг
# [111181003, 'Специалист в офис', 'Москва', 200000.0, 250000.0, False, 'RUR', 'Самолет Плюс Мск Юг']
# 111347636,Junior Project Manager,Москва,100000.0,130000.0,False,RUR,Red Dynamics
# [111347636, 'Junior Project Manager', 'Москва', 100000.0, 130000.0, False, 'RUR', 'Red Dynamics']
# 106777138,Тестировщик,Москва,180000.0,,True,RUR,ABCP
# [106777138, 'Тестировщик', 'Москва', 180000.0, None, True, 'RUR', 'ABCP']
# 112600863,Backend-разработчик,Москва,350000.0,400000.0,False,RUR,Филиал The Visa Services в г. Москва
# [112600863, 'Backend-разработчик', 'Москва', 350000.0, 400000.0, False, 'RUR', 'Филиал The Visa Services в г. Москва']
# 111898087,Middle+ Backend Developer,Москва,220000.0,270000.0,False,RUR,Перспектива
# [111898087, 'Middle+ Backend Developer', 'Москва', 220000.0, 270000.0, False, 'RUR', 'Перспектива']
# 112732005,Unity-разработчик,Москва,20000.0,20000.0,False,RUR,Родионов А.В.
# [112732005, 'Unity-разработчик', 'Москва', 20000.0, 20000.0, False, 'RUR', 'Родионов А.В.']
# 112770021,Программист-разработчик,Москва,150000.0,200000.0,False,RUR,Вершинина Евгения Михайловна
# [112770021, 'Программист-разработчик', 'Москва', 150000.0, 200000.0, False, 'RUR', 'Вершинина Евгения Михайловна']
# 111224530,Младший проджект-менеджер,Москва,70000.0,80000.0,False,RUR,Зимние Игры
# [111224530, 'Младший проджект-менеджер', 'Москва', 70000.0, 80000.0, False, 'RUR', 'Зимние Игры']
# 112607852,Go/Golang разработчик,Москва,140000.0,160000.0,False,RUR,Пиксель Квест
# [112607852, 'Go/Golang разработчик', 'Москва', 140000.0, 160000.0, False, 'RUR', 'Пиксель Квест']
# 112746927,Senior iOS разработчик (Гибрид),Москва,,550000.0,True,RUR,Offer Now
# [112746927, 'Senior iOS разработчик (Гибрид)', 'Москва', None, 550000.0, True, 'RUR', 'Offer Now']
# 111010938,Frontend-разработчик (Middle),Москва,100000.0,,False,RUR,Павлова Дарья Евгеньевна
# [111010938, 'Frontend-разработчик (Middle)', 'Москва', 100000.0, None, False, 'RUR', 'Павлова Дарья Евгеньевна']
# 111350374,Prompt-engineer,Москва,100000.0,300000.0,False,RUR,Нейросети
# [111350374, 'Prompt-engineer', 'Москва', 100000.0, 300000.0, False, 'RUR', 'Нейросети']
# 111507616,"Frontend-разработчик (Middle, Middle+)",Москва,180000.0,220000.0,False,RUR,HR-PROFI
# [111507616, 'Frontend-разработчик (Middle, Middle+)', 'Москва', 180000.0, 220000.0, False, 'RUR', 'HR-PROFI']
# 111085708,Frontend-разработчик React.js,Москва,120000.0,,False,RUR,Appbooster
# [111085708, 'Frontend-разработчик React.js', 'Москва', 120000.0, None, False, 'RUR', 'Appbooster']
# 111426994,QA Manual (гибрид),Москва,120000.0,170000.0,False,RUR,RecruitTech
# [111426994, 'QA Manual (гибрид)', 'Москва', 120000.0, 170000.0, False, 'RUR', 'RecruitTech']
# 112432620,CTO/Руководитель отдела разработки,Москва,400000.0,600000.0,False,RUR,Перспектива
# [112432620, 'CTO/Руководитель отдела разработки', 'Москва', 400000.0, 600000.0, False, 'RUR', 'Перспектива']
# 108391735,Frontend-разработчик,Москва,135000.0,,False,RUR,Онлайн-гимназия
# [108391735, 'Frontend-разработчик', 'Москва', 135000.0, None, False, 'RUR', 'Онлайн-гимназия']
# 112692556,Начальник отдела правового сопровождения инвестиционных проектов,Москва,,300000.0,False,RUR,Agalarov Development
# [112692556, 'Начальник отдела правового сопровождения инвестиционных проектов', 'Москва', None, 300000.0, False, 'RUR', 'Agalarov Development']
# 112700149,Java-разработчик (developer),Москва,250000.0,,False,RUR,Северный Ветер
# [112700149, 'Java-разработчик (developer)', 'Москва', 250000.0, None, False, 'RUR', 'Северный Ветер']
# 110754696,Middle Frontend developer,Москва,200000.0,,True,RUR,БКХ Еком
# [110754696, 'Middle Frontend developer', 'Москва', 200000.0, None, True, 'RUR', 'БКХ Еком']
# 111052115,Manual QA,Москва,150000.0,,False,RUR,Ассоциация IPChain
# [111052115, 'Manual QA', 'Москва', 150000.0, None, False, 'RUR', 'Ассоциация IPChain']
# 112520027,Customer support specialist / специалист клиентской поддержки,Москва,,120000.0,False,RUR,MSG
# [112520027, 'Customer support specialist / специалист клиентской поддержки', 'Москва', None, 120000.0, False, 'RUR', 'MSG']
# 112775424,Senior Front-End разработчик JS,Москва,190000.0,,False,RUR,ТНГ ГРУПП
# [112775424, 'Senior Front-End разработчик JS', 'Москва', 190000.0, None, False, 'RUR', 'ТНГ ГРУПП']
# 108452364,Менеджер по подбору персонала,Москва,80000.0,,False,RUR,ИКС-ПРО
# [108452364, 'Менеджер по подбору персонала', 'Москва', 80000.0, None, False, 'RUR', 'ИКС-ПРО']
# 112591354,Python-разработчик,Москва,180000.0,,False,RUR,Аликсон
# [112591354, 'Python-разработчик', 'Москва', 180000.0, None, False, 'RUR', 'Аликсон']
# 112568686,Java разработчик в проект Электронная отчетность,Москва,,250000.0,False,RUR,Платформа ОФД
# [112568686, 'Java разработчик в проект Электронная отчетность', 'Москва', None, 250000.0, False, 'RUR', 'Платформа ОФД']
# 112590067,Технический писатель,Москва,,250000.0,False,RUR,Monnect
# [112590067, 'Технический писатель', 'Москва', None, 250000.0, False, 'RUR', 'Monnect']
# 112449978,Графический дизайнер (удаленно),Москва,70000.0,90000.0,True,RUR,Группа компаний МЕДСИ
# [112449978, 'Графический дизайнер (удаленно)', 'Москва', 70000.0, 90000.0, True, 'RUR', 'Группа компаний МЕДСИ']
# 112375107,Python Middle Developer,Москва,100000.0,,True,RUR,СМАРЕНТ
# [112375107, 'Python Middle Developer', 'Москва', 100000.0, None, True, 'RUR', 'СМАРЕНТ']
# 112518493,Стажер,Москва,50000.0,,False,RUR,Витте Консалтинг
# [112518493, 'Стажер', 'Москва', 50000.0, None, False, 'RUR', 'Витте Консалтинг']
# 110646300,Junior разработчик Python/Стажер (удаленно),Москва,,50000.0,False,RUR,Андреев Артём Александрович
# [110646300, 'Junior разработчик Python/Стажер (удаленно)', 'Москва', None, 50000.0, False, 'RUR', 'Андреев Артём Александрович']
# 111437020,Middle frontend developer (react),Москва,100000.0,160000.0,False,RUR,Фабрика Решений
# [111437020, 'Middle frontend developer (react)', 'Москва', 100000.0, 160000.0, False, 'RUR', 'Фабрика Решений']
# 111742642,Frontend-разработчик,Москва,,200000.0,True,RUR,BND LLC
# [111742642, 'Frontend-разработчик', 'Москва', None, 200000.0, True, 'RUR', 'BND LLC']
# 111448134,Системный аналитик,Москва,150000.0,,False,RUR,Domeo
# [111448134, 'Системный аналитик', 'Москва', 150000.0, None, False, 'RUR', 'Domeo']
# 112602566,Администратор,Москва,110000.0,,False,RUR,LEGENDA
# [112602566, 'Администратор', 'Москва', 110000.0, None, False, 'RUR', 'LEGENDA']
# 111723682,Операционный директор правового блока,Москва,,1000000.0,False,RUR,RecruitTech
# [111723682, 'Операционный директор правового блока', 'Москва', None, 1000000.0, False, 'RUR', 'RecruitTech']
# 112550259,PHP Разработчик (backend),Москва,1800.0,,False,USD,A1 SolarStore
# [112550259, 'PHP Разработчик (backend)', 'Москва', 1800.0, None, False, 'USD', 'A1 SolarStore']
# 112366420,Специалист по сборке электронных курсов,Москва,50000.0,75000.0,True,RUR,Логрус АйТи
# [112366420, 'Специалист по сборке электронных курсов', 'Москва', 50000.0, 75000.0, True, 'RUR', 'Логрус АйТи']
# 112237717,Frontend-разработчик ReactJS,Москва,80000.0,140000.0,False,RUR,"Юнити,ООО"
# [112237717, 'Frontend-разработчик ReactJS', 'Москва', 80000.0, 140000.0, False, 'RUR', 'Юнити,ООО']
# 112614387,SAP ABAP Developer (to Germany),Москва,,4500.0,False,EUR,Transparent Hiring
# [112614387, 'SAP ABAP Developer (to Germany)', 'Москва', None, 4500.0, False, 'EUR', 'Transparent Hiring']
# 111424761,Системный аналитик (стажер),Москва,100000.0,,True,RUR,Аминева Елизавета
# [111424761, 'Системный аналитик (стажер)', 'Москва', 100000.0, None, True, 'RUR', 'Аминева Елизавета']
# 112679677,C#/.NET-разработчик,Москва,170000.0,210000.0,False,RUR,Группа компаний МЕДСИ
# [112679677, 'C#/.NET-разработчик', 'Москва', 170000.0, 210000.0, False, 'RUR', 'Группа компаний МЕДСИ']
# 112001765,Разработчик C++,Москва,100000.0,105000.0,False,RUR,Макаров Алексей
# [112001765, 'Разработчик C++', 'Москва', 100000.0, 105000.0, False, 'RUR', 'Макаров Алексей']
# 112696773,Тестировщик Яндекс Браузера,Москва,,66000.0,False,RUR,Яндекс Крауд
# [112696773, 'Тестировщик Яндекс Браузера', 'Москва', None, 66000.0, False, 'RUR', 'Яндекс Крауд']
# 112590428,Графический дизайнер / Веб дизайнер / Дизайнер для мероприятий,Москва,150000.0,180000.0,False,RUR,РБ.РУ
# [112590428, 'Графический дизайнер / Веб дизайнер / Дизайнер для мероприятий', 'Москва', 150000.0, 180000.0, False, 'RUR', 'РБ.РУ']
# 112438916,Unity-разработчик,Москва,,1000.0,True,USD,Pimpochka Games
# [112438916, 'Unity-разработчик', 'Москва', None, 1000.0, True, 'USD', 'Pimpochka Games']
# 111853662,Business development manager / BDM / BizDev (web3),Москва,1500.0,,False,USD,HR ME
# [111853662, 'Business development manager / BDM / BizDev (web3)', 'Москва', 1500.0, None, False, 'USD', 'HR ME']
# 112732591,PHP-разработчик,Москва,130000.0,200000.0,True,RUR,Sibdev
# [112732591, 'PHP-разработчик', 'Москва', 130000.0, 200000.0, True, 'RUR', 'Sibdev']
# 112737061,Младший бизнес-аналитик / стажёр,Москва,,50000.0,False,RUR,Радиум
# [112737061, 'Младший бизнес-аналитик / стажёр', 'Москва', None, 50000.0, False, 'RUR', 'Радиум']
# 108972672,Специалист поддержки партнеров (Telegram),Москва,30000.0,30000.0,False,RUR,Travelask.ru
# [108972672, 'Специалист поддержки партнеров (Telegram)', 'Москва', 30000.0, 30000.0, False, 'RUR', 'Travelask.ru']
# 112704230,Оператор чата,Москва,,33000.0,False,RUR,Гринлид Групп
# [112704230, 'Оператор чата', 'Москва', None, 33000.0, False, 'RUR', 'Гринлид Групп']
# 111220057,Техник на складе (бытовая техника),Москва,60000.0,70000.0,True,RUR,Райт Скан
# [111220057, 'Техник на складе (бытовая техника)', 'Москва', 60000.0, 70000.0, True, 'RUR', 'Райт Скан']
# 112714679,Junior Fullstack разработчик в офис,Москва,100000.0,,False,RUR,Ветростиль
# [112714679, 'Junior Fullstack разработчик в офис', 'Москва', 100000.0, None, False, 'RUR', 'Ветростиль']
# 112626637,UX/UI-дизайнер,Москва,120000.0,,True,RUR,Ювикам и Ко
# [112626637, 'UX/UI-дизайнер', 'Москва', 120000.0, None, True, 'RUR', 'Ювикам и Ко']
# 112749416,Frontend-разработчик Middle+ (Vue),Москва,150000.0,,False,RUR,ЭИР Продакшн
# [112749416, 'Frontend-разработчик Middle+ (Vue)', 'Москва', 150000.0, None, False, 'RUR', 'ЭИР Продакшн']
# 108789972,Тестировщик,Москва,100000.0,,False,RUR,Carcade Leasing
# [108789972, 'Тестировщик', 'Москва', 100000.0, None, False, 'RUR', 'Carcade Leasing']
# 112743788,UX/UI дизайнер IT-франшиз,Москва,120000.0,150000.0,False,RUR,Singular-IT
# [112743788, 'UX/UI дизайнер IT-франшиз', 'Москва', 120000.0, 150000.0, False, 'RUR', 'Singular-IT']
# 111843910,Frontend-разработчик (middle),Москва,215000.0,,True,RUR,Секьюр-Ти
# [111843910, 'Frontend-разработчик (middle)', 'Москва', 215000.0, None, True, 'RUR', 'Секьюр-Ти']
# 109676257,Контент-менеджер сайтов,Москва,35000.0,,False,RUR,OVERCLICK
# [109676257, 'Контент-менеджер сайтов', 'Москва', 35000.0, None, False, 'RUR', 'OVERCLICK']
# 112771380,Ведущий веб-дизайнер UX/UI,Москва,120000.0,150000.0,False,RUR,ДМТ групп
# [112771380, 'Ведущий веб-дизайнер UX/UI', 'Москва', 120000.0, 150000.0, False, 'RUR', 'ДМТ групп']
# 112748802,Программист-разработчик,Москва,350000.0,400000.0,False,RUR,Mega Personal Регионы
# [112748802, 'Программист-разработчик', 'Москва', 350000.0, 400000.0, False, 'RUR', 'Mega Personal Регионы']
# 112415283,Team Leader | Art Director,Москва,250000.0,350000.0,False,RUR,MARTA
# [112415283, 'Team Leader | Art Director', 'Москва', 250000.0, 350000.0, False, 'RUR', 'MARTA']
# 111961404,Frontend-разработчик,Москва,,200000.0,False,RUR,DV-Consulting
# [111961404, 'Frontend-разработчик', 'Москва', None, 200000.0, False, 'RUR', 'DV-Consulting']
# 112729146,Маркетолог-аналитик,Москва,150000.0,,False,RUR,Zoletto
# [112729146, 'Маркетолог-аналитик', 'Москва', 150000.0, None, False, 'RUR', 'Zoletto']
# 107395830,Java-разработчик,Москва,150000.0,200000.0,True,RUR,Снэп АйТи
# [107395830, 'Java-разработчик', 'Москва', 150000.0, 200000.0, True, 'RUR', 'Снэп АйТи']
# 111792564,Middle Python Backend Developer,Москва,160000.0,220000.0,False,RUR,Vortex
# [111792564, 'Middle Python Backend Developer', 'Москва', 160000.0, 220000.0, False, 'RUR', 'Vortex']
# 111443435,Junior QA engineer,Москва,600.0,1000.0,False,USD,Hodl Hodl
# [111443435, 'Junior QA engineer', 'Москва', 600.0, 1000.0, False, 'USD', 'Hodl Hodl']
# 112354041,IT Project manager (junior),Москва,125000.0,,False,RUR,Валта
# [112354041, 'IT Project manager (junior)', 'Москва', 125000.0, None, False, 'RUR', 'Валта']
# 112579543,Специалист клиентской поддержки (Customer support manager),Москва,,100000.0,False,RUR,Mindbox
# [112579543, 'Специалист клиентской поддержки (Customer support manager)', 'Москва', None, 100000.0, False, 'RUR', 'Mindbox']
# 112713322,Python разработчик,Москва,,250000.0,False,RUR,РБК
# [112713322, 'Python разработчик', 'Москва', None, 250000.0, False, 'RUR', 'РБК']
# 111504613,Директор по строительству (индивидуальное малоэтажное строительство),Москва,1000000.0,,False,RUR,MAAR DEVELOPMENT
# [111504613, 'Директор по строительству (индивидуальное малоэтажное строительство)', 'Москва', 1000000.0, None, False, 'RUR', 'MAAR DEVELOPMENT']
# 112507512,Специалист дистанционного обучения (Websoft),Москва,200000.0,200000.0,False,RUR,NOVAROLL
# [112507512, 'Специалист дистанционного обучения (Websoft)', 'Москва', 200000.0, 200000.0, False, 'RUR', 'NOVAROLL']
# 112772568,Тестировщик / специалист технической поддержки,Москва,50000.0,80000.0,False,RUR,Selsup
# [112772568, 'Тестировщик / специалист технической поддержки', 'Москва', 50000.0, 80000.0, False, 'RUR', 'Selsup']
# 110999730,UX/UI дизайнер / Продуктовый дизайнер (Junior+/Middle),Москва,70000.0,110000.0,False,RUR,Mish Design
# [110999730, 'UX/UI дизайнер / Продуктовый дизайнер (Junior+/Middle)', 'Москва', 70000.0, 110000.0, False, 'RUR', 'Mish Design']
# 111536787,Менеджер по работе с ключевыми клиентами,Москва,150000.0,,False,RUR,Ситипоинт
# [111536787, 'Менеджер по работе с ключевыми клиентами', 'Москва', 150000.0, None, False, 'RUR', 'Ситипоинт']
# 112440342,IT Project Manager,Москва,1700.0,2050.0,False,USD,DevCube
# [112440342, 'IT Project Manager', 'Москва', 1700.0, 2050.0, False, 'USD', 'DevCube']
# 112334914,Middle специалист по контекстной рекламе/Директолог(гибрид),Москва,150000.0,,False,RUR,ТУРКОВ
# [112334914, 'Middle специалист по контекстной рекламе/Директолог(гибрид)', 'Москва', 150000.0, None, False, 'RUR', 'ТУРКОВ']
# 112576428,Продакт-менеджер (Selection),Москва,280000.0,,True,RUR,Лэтуаль Диджитал
# [112576428, 'Продакт-менеджер (Selection)', 'Москва', 280000.0, None, True, 'RUR', 'Лэтуаль Диджитал']
# 110876155,Начинающий Project Manager (IT),Москва,90000.0,125000.0,False,RUR,Альянс
# [110876155, 'Начинающий Project Manager (IT)', 'Москва', 90000.0, 125000.0, False, 'RUR', 'Альянс']
# 111970337,Системный аналитик,Москва,250000.0,,False,RUR,В Кадре
# [111970337, 'Системный аналитик', 'Москва', 250000.0, None, False, 'RUR', 'В Кадре']
# 112405967,Начальник отдела финансового анализа,Москва,270000.0,,False,RUR,Холдинговая компания Новолекс
# [112405967, 'Начальник отдела финансового анализа', 'Москва', 270000.0, None, False, 'RUR', 'Холдинговая компания Новолекс']
# 110797718,Frontend разработчик (Middle),Москва,150000.0,200000.0,False,RUR,Оптимальные системы
# [110797718, 'Frontend разработчик (Middle)', 'Москва', 150000.0, 200000.0, False, 'RUR', 'Оптимальные системы']
# 112072184,Business development manager (Gambling),Москва,100000.0,220000.0,False,RUR,X-partners
# [112072184, 'Business development manager (Gambling)', 'Москва', 100000.0, 220000.0, False, 'RUR', 'X-partners']
# 112647267,IOS-разработчик,Москва,,400000.0,True,RUR,Артвелл
# [112647267, 'IOS-разработчик', 'Москва', None, 400000.0, True, 'RUR', 'Артвелл']
# 112573206,"Менеджер по пожарной безопасности, ГО, ЧС и безопасности",Москва,,190000.0,True,RUR,ADG group
# [112573206, 'Менеджер по пожарной безопасности, ГО, ЧС и безопасности', 'Москва', None, 190000.0, True, 'RUR', 'ADG group']
# 108988570,Junior Frontend Developer React,Москва,60000.0,,False,RUR,Sycret.ru
# [108988570, 'Junior Frontend Developer React', 'Москва', 60000.0, None, False, 'RUR', 'Sycret.ru']
# 111613817,Account manager (Аккаунт менеджер) IT,Москва,1200.0,,False,USD,Жукова Мария Юрьевна
# [111613817, 'Account manager (Аккаунт менеджер) IT', 'Москва', 1200.0, None, False, 'USD', 'Жукова Мария Юрьевна']
# 112357514,Frontend developer,Москва,2000.0,3100.0,False,USD,Appie.tech
# [112357514, 'Frontend developer', 'Москва', 2000.0, 3100.0, False, 'USD', 'Appie.tech']
# 110958893,Frontend-разработчик,Москва,50000.0,220000.0,False,RUR,AVS Consulting
# [110958893, 'Frontend-разработчик', 'Москва', 50000.0, 220000.0, False, 'RUR', 'AVS Consulting']
# 112748658,Тимлид B2B продаж / Sales & Business Development Executive,Москва,200000.0,,False,RUR,SMS Aero
# [112748658, 'Тимлид B2B продаж / Sales & Business Development Executive', 'Москва', 200000.0, None, False, 'RUR', 'SMS Aero']
# 112504163,Персональный водитель руководителя,Москва,,120000.0,True,RUR,"Пионер, Группа компаний"
# [112504163, 'Персональный водитель руководителя', 'Москва', None, 120000.0, True, 'RUR', 'Пионер, Группа компаний']
# 109210282,Проджект-менеджер/Аналитик,Москва,,200000.0,False,RUR,AISA
# [109210282, 'Проджект-менеджер/Аналитик', 'Москва', None, 200000.0, False, 'RUR', 'AISA']
# 109144502,Специалист контроля качества,Москва,30000.0,45000.0,False,RUR,Travelask.ru
# [109144502, 'Специалист контроля качества', 'Москва', 30000.0, 45000.0, False, 'RUR', 'Travelask.ru']
# 112741710,Дизайнер-верстальщик,Москва,45000.0,45000.0,True,RUR,Гарант
# [112741710, 'Дизайнер-верстальщик', 'Москва', 45000.0, 45000.0, True, 'RUR', 'Гарант']
# 111757941,Стажер в команду тестирования / QA Intern,Москва,50000.0,,True,RUR,Кокалевский Алексей Алексеевич
# [111757941, 'Стажер в команду тестирования / QA Intern', 'Москва', 50000.0, None, True, 'RUR', 'Кокалевский Алексей Алексеевич']
# 112774797,Бухгалтер - экономист,Москва,80000.0,,False,RUR,Эдстрим Диджитал
# [112774797, 'Бухгалтер - экономист', 'Москва', 80000.0, None, False, 'RUR', 'Эдстрим Диджитал']
# 112351814,Head of Sales,Москва,300000.0,,True,RUR,OpenHiring
# [112351814, 'Head of Sales', 'Москва', 300000.0, None, True, 'RUR', 'OpenHiring']
# 112665371,"Junior+ QA Engineer (SaaS, e-commerce)",Москва,60000.0,90000.0,False,RUR,DIGINETICA
# [112665371, 'Junior+ QA Engineer (SaaS, e-commerce)', 'Москва', 60000.0, 90000.0, False, 'RUR', 'DIGINETICA']
# 112703711,Заместитель главного редактора в отраслевое СМИ,Москва,,150000.0,False,RUR,"Рубеж, Группа компаний"
# [112703711, 'Заместитель главного редактора в отраслевое СМИ', 'Москва', None, 150000.0, False, 'RUR', 'Рубеж, Группа компаний']
# 112325053,Разработчик Java / Java Developer (middle),Москва,,250000.0,False,RUR,АГ-Логистик
# [112325053, 'Разработчик Java / Java Developer (middle)', 'Москва', None, 250000.0, False, 'RUR', 'АГ-Логистик']
# 109412850,C#/.NET-разработчик,Москва,175000.0,,True,RUR,Мэйджор Терминал
# [109412850, 'C#/.NET-разработчик', 'Москва', 175000.0, None, True, 'RUR', 'Мэйджор Терминал']
# 112506448,Оператор call-центра (на проект),Москва,90000.0,,False,RUR,Ricci | Жилая недвижимость
# [112506448, 'Оператор call-центра (на проект)', 'Москва', 90000.0, None, False, 'RUR', 'Ricci | Жилая недвижимость']
# 112582184,Офис-менеджер/ассистент руководителя,Москва,100000.0,110000.0,False,RUR,Примула
# [112582184, 'Офис-менеджер/ассистент руководителя', 'Москва', 100000.0, 110000.0, False, 'RUR', 'Примула']
# 111875122,Java Developer Middle+ (fintech project),Москва,250000.0,350000.0,False,RUR,Картнода
# [111875122, 'Java Developer Middle+ (fintech project)', 'Москва', 250000.0, 350000.0, False, 'RUR', 'Картнода']
# 111536666,Инженер-тестировщик ПО,Москва,80000.0,100000.0,False,RUR,FINTECH CORE
# [111536666, 'Инженер-тестировщик ПО', 'Москва', 80000.0, 100000.0, False, 'RUR', 'FINTECH CORE']
# 112592579,React-разработчик_middle (удалённо с территории РФ),Москва,,250000.0,False,RUR,Amex Development
# [112592579, 'React-разработчик_middle (удалённо с территории РФ)', 'Москва', None, 250000.0, False, 'RUR', 'Amex Development']
# 111886658,Senior Developer ( C#/blockchain ),Москва,350000.0,600000.0,False,RUR,Брисмани
# [111886658, 'Senior Developer ( C#/blockchain )', 'Москва', 350000.0, 600000.0, False, 'RUR', 'Брисмани']
# 112448549,Специалист НСИ,Москва,100000.0,150000.0,False,RUR,Форт
# [112448549, 'Специалист НСИ', 'Москва', 100000.0, 150000.0, False, 'RUR', 'Форт']
# 112250837,Программист C++ Junior,Москва,50000.0,,False,RUR,Петров Игорь Кириллович
# [112250837, 'Программист C++ Junior', 'Москва', 50000.0, None, False, 'RUR', 'Петров Игорь Кириллович']
# 112579873,.NET разработчик,Москва,,400000.0,False,RUR,Monnect
# [112579873, '.NET разработчик', 'Москва', None, 400000.0, False, 'RUR', 'Monnect']
# 111264221,Главный инженер,Москва,4000.0,,False,USD,ESI Technology
# [111264221, 'Главный инженер', 'Москва', 4000.0, None, False, 'USD', 'ESI Technology']
# 112689857,Офис-менеджер (отдел продаж 2/2),Москва,,93500.0,False,RUR,Хаттон Девелопмент
# [112689857, 'Офис-менеджер (отдел продаж 2/2)', 'Москва', None, 93500.0, False, 'RUR', 'Хаттон Девелопмент']
# 112706687,Ведущий программист 1С,Москва,400000.0,,True,RUR,ЛИГА
# [112706687, 'Ведущий программист 1С', 'Москва', 400000.0, None, True, 'RUR', 'ЛИГА']
# 111347055,Mobile Developer,Москва,60000.0,,False,RUR,ЮниСейф
# [111347055, 'Mobile Developer', 'Москва', 60000.0, None, False, 'RUR', 'ЮниСейф']
# 112423062,Node.js разработчик,Москва,200000.0,220000.0,False,RUR,aQsi
# [112423062, 'Node.js разработчик', 'Москва', 200000.0, 220000.0, False, 'RUR', 'aQsi']
# 112409078,Контент-менеджер,Москва,80000.0,,False,RUR,MILANA Shoes & Accessories
# [112409078, 'Контент-менеджер', 'Москва', 80000.0, None, False, 'RUR', 'MILANA Shoes & Accessories']
# 112431165,Middle PHP developer,Москва,180000.0,250000.0,True,RUR,Оджетто
# [112431165, 'Middle PHP developer', 'Москва', 180000.0, 250000.0, True, 'RUR', 'Оджетто']
# 112750446,Диспетчер (дежурный),Москва,76000.0,,False,RUR,РТ-ТехСервис
# [112750446, 'Диспетчер (дежурный)', 'Москва', 76000.0, None, False, 'RUR', 'РТ-ТехСервис']
# 112627495,DevOps инженер (junior +),Москва,80000.0,120000.0,False,RUR,Страховые Партнеры
# [112627495, 'DevOps инженер (junior +)', 'Москва', 80000.0, 120000.0, False, 'RUR', 'Страховые Партнеры']
# 110794336,Младший системный аналитик,Москва,80000.0,140000.0,False,RUR,Soar high software
# [110794336, 'Младший системный аналитик', 'Москва', 80000.0, 140000.0, False, 'RUR', 'Soar high software']
# 112795525,Java-разработчик,Москва,,340000.0,False,RUR,Точка
# [112795525, 'Java-разработчик', 'Москва', None, 340000.0, False, 'RUR', 'Точка']
# 112036170,Юрист Gamedev,Москва,180000.0,,False,RUR,AYA GAMES
# [112036170, 'Юрист Gamedev', 'Москва', 180000.0, None, False, 'RUR', 'AYA GAMES']
# 112539745,Middle/Middle+ PHP Developer,Москва,200000.0,250000.0,True,RUR,Компания 05.ру
# [112539745, 'Middle/Middle+ PHP Developer', 'Москва', 200000.0, 250000.0, True, 'RUR', 'Компания 05.ру']
# 112741875,Project / Product Manager - Менеджер Продукта и Проектов IT Fintech (Дубай),Москва,220000.0,300000.0,False,RUR,Nexus Hub
# ...
# 108817065,Главный бухгалтер,Москва,300000.0,,True,RUR,ПРОФИЛАБТЕСТ
# [108817065, 'Главный бухгалтер', 'Москва', 300000.0, None, True, 'RUR', 'ПРОФИЛАБТЕСТ']
# 110715621,Frontend React,Москва,150000.0,,False,RUR,VSporte
# [110715621, 'Frontend React', 'Москва', 150000.0, None, False, 'RUR', 'VSporte']
# 111527361,Тестировщик роборуки,Москва,50000.0,68000.0,False,RUR,Яндекс Крауд
# [111527361, 'Тестировщик роборуки', 'Москва', 50000.0, 68000.0, False, 'RUR', 'Яндекс Крауд']
# 111883857,Backend-разработчик Python (Junior+),Москва,,150000.0,True,RUR,Мамаева Ирина Анатольевна
# [111883857, 'Backend-разработчик Python (Junior+)', 'Москва', None, 150000.0, True, 'RUR', 'Мамаева Ирина Анатольевна']
# 112713015,Product manager,Москва,180000.0,,True,RUR,Клерк.Ру
# [112713015, 'Product manager', 'Москва', 180000.0, None, True, 'RUR', 'Клерк.Ру']
# 110600404,Системный аналитик,Москва,60000.0,90000.0,False,RUR,Фьюче
# [110600404, 'Системный аналитик', 'Москва', 60000.0, 90000.0, False, 'RUR', 'Фьюче']
# 110960478,QA специалист (финтех),Москва,,200000.0,True,RUR,Data World
# [110960478, 'QA специалист (финтех)', 'Москва', None, 200000.0, True, 'RUR', 'Data World']
# 112320385,Разработчик С#,Москва,,270000.0,False,RUR,Дивергент
# [112320385, 'Разработчик С#', 'Москва', None, 270000.0, False, 'RUR', 'Дивергент']
# 111056113,Тендерный специалист,Москва,200000.0,500000.0,False,RUR,Арес
# [111056113, 'Тендерный специалист', 'Москва', 200000.0, 500000.0, False, 'RUR', 'Арес']
# 112140875,Тестировщик ПО / QA Инженер Python,Москва,150000.0,250000.0,False,RUR,ДипХакЛаб
# [112140875, 'Тестировщик ПО / QA Инженер Python', 'Москва', 150000.0, 250000.0, False, 'RUR', 'ДипХакЛаб']
# 111576799,Инженер-тестировщик ПО / Middle QA-engineer,Москва,150000.0,,True,RUR,"ФортХХI, НПП"
# [111576799, 'Инженер-тестировщик ПО / Middle QA-engineer', 'Москва', 150000.0, None, True, 'RUR', 'ФортХХI, НПП']
# 112694547,Бухгалтер / Финансовый аналитик,Москва,65000.0,100000.0,False,RUR,Ursa Team
# [112694547, 'Бухгалтер / Финансовый аналитик', 'Москва', 65000.0, 100000.0, False, 'RUR', 'Ursa Team']
# 112594469,Оператор чата контактного центра,Москва,50000.0,,True,RUR,Диджитал медикэл оперейшнс
# [112594469, 'Оператор чата контактного центра', 'Москва', 50000.0, None, True, 'RUR', 'Диджитал медикэл оперейшнс']
# 111877174,Python-разработчик,Москва,,250000.0,False,RUR,Avalon-IT
# [111877174, 'Python-разработчик', 'Москва', None, 250000.0, False, 'RUR', 'Avalon-IT']
# 112238541,Менеджер по персоналу / HR (IT),Москва,100000.0,150000.0,False,RUR,Первый Бит
# [112238541, 'Менеджер по персоналу / HR (IT)', 'Москва', 100000.0, 150000.0, False, 'RUR', 'Первый Бит']
# 112606036,IT Project Manager,Москва,180000.0,250000.0,False,RUR,Компания ИнфоТек
# [112606036, 'IT Project Manager', 'Москва', 180000.0, 250000.0, False, 'RUR', 'Компания ИнфоТек']
# 112646191,"Начинающий Typescript fullstack разработчик NestJS, React",Москва,,90000.0,False,RUR,КОДМАРК
# [112646191, 'Начинающий Typescript fullstack разработчик NestJS, React', 'Москва', None, 90000.0, False, 'RUR', 'КОДМАРК']
# 110444980,Data Analyst / Аналитик данных,Москва,200000.0,,True,RUR,Procter & Gamble
# [110444980, 'Data Analyst / Аналитик данных', 'Москва', 200000.0, None, True, 'RUR', 'Procter & Gamble']
# 111342701,Системный администратор,Москва,184000.0,,True,RUR,"РУНА, консалтинговая группа"
# [111342701, 'Системный администратор', 'Москва', 184000.0, None, True, 'RUR', 'РУНА, консалтинговая группа']
# 112317575,Веб-дизайнер,Москва,50000.0,80000.0,False,RUR,Maryproject
# [112317575, 'Веб-дизайнер', 'Москва', 50000.0, 80000.0, False, 'RUR', 'Maryproject']
# 111115191,Менеджер по продажам B2B,Москва,200000.0,,False,RUR,Майсэплай
# [111115191, 'Менеджер по продажам B2B', 'Москва', 200000.0, None, False, 'RUR', 'Майсэплай']
# 112448577,"Frontend разработчик (Telegram Mini App, Phaser - Gamedev)",Москва,70000.0,120000.0,False,RUR,Girls And Robots
# [112448577, 'Frontend разработчик (Telegram Mini App, Phaser - Gamedev)', 'Москва', 70000.0, 120000.0, False, 'RUR', 'Girls And Robots']
# 112708549,Специалист сопровождения собственного ПО,Москва,90000.0,110000.0,False,RUR,МЦ-Сервис Инжиниринг
# [112708549, 'Специалист сопровождения собственного ПО', 'Москва', 90000.0, 110000.0, False, 'RUR', 'МЦ-Сервис Инжиниринг']
# 112756380,Инженер-тестировщик ВНИМАНИЕ! РЕЖИМ РАБОТЫ В ОФИСЕ. УДАЛЕННЫЙ РЕЖИМ НЕ РАССМАТРИВАЕМ!!!!!,Москва,100000.0,100000.0,False,RUR,РПС
# [112756380, 'Инженер-тестировщик ВНИМАНИЕ! РЕЖИМ РАБОТЫ В ОФИСЕ. УДАЛЕННЫЙ РЕЖИМ НЕ РАССМАТРИВАЕМ!!!!!', 'Москва', 100000.0, 100000.0, False, 'RUR', 'РПС']
# 112442788,Rust Developer (blockchain),Москва,6000.0,7500.0,True,USD,EmFi Technologies Limited
# [112442788, 'Rust Developer (blockchain)', 'Москва', 6000.0, 7500.0, True, 'USD', 'EmFi Technologies Limited']
# 112709274,Главный бухгалтер,Москва,150000.0,,False,RUR,Фермерский чеснок
# [112709274, 'Главный бухгалтер', 'Москва', 150000.0, None, False, 'RUR', 'Фермерский чеснок']
# 91731813,Специалист службы технической поддержки клиентов (L2),Москва,120000.0,180000.0,False,RUR,Каллисто Вижн
# [91731813, 'Специалист службы технической поддержки клиентов (L2)', 'Москва', 120000.0, 180000.0, False, 'RUR', 'Каллисто Вижн']
# 112138468,Junior SEO-специалист,Москва,60000.0,70000.0,False,RUR,Студия веб-дизайна Digital Solutions
# [112138468, 'Junior SEO-специалист', 'Москва', 60000.0, 70000.0, False, 'RUR', 'Студия веб-дизайна Digital Solutions']
# 112452293,Backend-разработчик,Москва,100000.0,200000.0,False,RUR,Celestia AI
# [112452293, 'Backend-разработчик', 'Москва', 100000.0, 200000.0, False, 'RUR', 'Celestia AI']
# 111567843,Программист 1С,Москва,300000.0,,False,RUR,Группа компаний Агротек
# [111567843, 'Программист 1С', 'Москва', 300000.0, None, False, 'RUR', 'Группа компаний Агротек']
# 112353542,Руководитель IT проектов,Москва,,250000.0,False,RUR,Сибериан.Про
# [112353542, 'Руководитель IT проектов', 'Москва', None, 250000.0, False, 'RUR', 'Сибериан.Про']
# 110089862,Заместитель главного бухгалтера,Москва,260000.0,260000.0,True,RUR,ВТЕ ЮГО-ВОСТОК
# [110089862, 'Заместитель главного бухгалтера', 'Москва', 260000.0, 260000.0, True, 'RUR', 'ВТЕ ЮГО-ВОСТОК']
# 110958928,Оператор-программист станков с ЧПУ (ученик),Москва,50000.0,170000.0,True,RUR,Колтакова Татьяна Витальевна
# [110958928, 'Оператор-программист станков с ЧПУ (ученик)', 'Москва', 50000.0, 170000.0, True, 'RUR', 'Колтакова Татьяна Витальевна']
# 109309289,Руководитель проектов\ middle Project manager IT,Москва,,300000.0,False,RUR,ГОЛДЕНГУС
# [109309289, 'Руководитель проектов\\ middle Project manager IT', 'Москва', None, 300000.0, False, 'RUR', 'ГОЛДЕНГУС']
# 112595316,Web-разработчик/Технический специалист,Москва,950.0,,False,USD,Lead Profit
# [112595316, 'Web-разработчик/Технический специалист', 'Москва', 950.0, None, False, 'USD', 'Lead Profit']
# 110620259,Менеджер по работе с клиентами (English),Москва,200000.0,,False,RUR,Индгроз Сервис
# [110620259, 'Менеджер по работе с клиентами (English)', 'Москва', 200000.0, None, False, 'RUR', 'Индгроз Сервис']
# 107634517,"C# developer junior / middle (.net, full-stack / back-end)",Москва,100000.0,300000.0,False,RUR,Mindbox
# [107634517, 'C# developer junior / middle (.net, full-stack / back-end)', 'Москва', 100000.0, 300000.0, False, 'RUR', 'Mindbox']
# 112036682,Junior разработчик (fullstack),Москва,60000.0,,False,RUR,"АйТи Гео, ООО (IT GEO)"
# [112036682, 'Junior разработчик (fullstack)', 'Москва', 60000.0, None, False, 'RUR', 'АйТи Гео, ООО (IT GEO)']
# 112047738,Product manager / Менеджер продукта,Москва,4000.0,,False,EUR,Топассистент
# [112047738, 'Product manager / Менеджер продукта', 'Москва', 4000.0, None, False, 'EUR', 'Топассистент']
# 110655725,Project Manager (менеджер проектов),Москва,90000.0,150000.0,False,RUR,ONE TOUCH
# [110655725, 'Project Manager (менеджер проектов)', 'Москва', 90000.0, 150000.0, False, 'RUR', 'ONE TOUCH']
# 112783869,Инженер-сметчик,Москва,200000.0,,False,RUR,LOTS.Development
# [112783869, 'Инженер-сметчик', 'Москва', 200000.0, None, False, 'RUR', 'LOTS.Development']
# 109936469,Консультант 1С (Junior),Москва,180000.0,,False,RUR,Alpine floor
# [109936469, 'Консультант 1С (Junior)', 'Москва', 180000.0, None, False, 'RUR', 'Alpine floor']
# 112564914,Ведущий методист,Москва,120000.0,200000.0,False,RUR,Евсеев Сергей Владимирович
# [112564914, 'Ведущий методист', 'Москва', 120000.0, 200000.0, False, 'RUR', 'Евсеев Сергей Владимирович']
# 112762823,C++ разработчик,Москва,100000.0,200000.0,False,RUR,Восхождение
# [112762823, 'C++ разработчик', 'Москва', 100000.0, 200000.0, False, 'RUR', 'Восхождение']
# 112763085,Power BI разработчик,Москва,80000.0,,False,RUR,Data-Power
# [112763085, 'Power BI разработчик', 'Москва', 80000.0, None, False, 'RUR', 'Data-Power']
# 106241302,Purchasing Manager / Менеджер по закупкам,Москва,155000.0,,True,RUR,Procter & Gamble
# [106241302, 'Purchasing Manager / Менеджер по закупкам', 'Москва', 155000.0, None, True, 'RUR', 'Procter & Gamble']
# 111896798,Frontend React (Middle/Senior),Москва,,200000.0,False,RUR,ВИЗ
# [111896798, 'Frontend React (Middle/Senior)', 'Москва', None, 200000.0, False, 'RUR', 'ВИЗ']
# 111514443,Frontend-разработчик,Москва,100000.0,200000.0,False,RUR,Старт
# [111514443, 'Frontend-разработчик', 'Москва', 100000.0, 200000.0, False, 'RUR', 'Старт']
# 111976762,Frontend-разработчик,Москва,220000.0,,False,RUR,Гнездо.ру
# [111976762, 'Frontend-разработчик', 'Москва', 220000.0, None, False, 'RUR', 'Гнездо.ру']
# 110631195,Fullstack-разработчик,Москва,220000.0,250000.0,True,RUR,Butler
# [110631195, 'Fullstack-разработчик', 'Москва', 220000.0, 250000.0, True, 'RUR', 'Butler']
# 110758353,Младший программист,Санкт-Петербург,30000.0,50000.0,False,RUR,Медицинские электронные данные
# [110758353, 'Младший программист', 'Санкт-Петербург', 30000.0, 50000.0, False, 'RUR', 'Медицинские электронные данные']
# 110810338,Ассистент менеджеров проектов/Младший менеджер проектов,Москва,30000.0,40000.0,False,RUR,Cetera
# [110810338, 'Ассистент менеджеров проектов/Младший менеджер проектов', 'Москва', 30000.0, 40000.0, False, 'RUR', 'Cetera']
# 112185460,Junior/Junior+php программист (стажёр),Москва,30000.0,,False,RUR,Ельмикеев Евгений Иванович
# [112185460, 'Junior/Junior+php программист (стажёр)', 'Москва', 30000.0, None, False, 'RUR', 'Ельмикеев Евгений Иванович']
# 110886726,Оператор call-центра,Москва,60000.0,100000.0,False,RUR,MONTRЁ clinic (Краснова Инна Юрьевна)
# [110886726, 'Оператор call-центра', 'Москва', 60000.0, 100000.0, False, 'RUR', 'MONTRЁ clinic (Краснова Инна Юрьевна)']
# 111439138,Ведущий инженер-конструктор (проектирование),Москва,150000.0,,False,RUR,Сибирь
# [111439138, 'Ведущий инженер-конструктор (проектирование)', 'Москва', 150000.0, None, False, 'RUR', 'Сибирь']
# 112794615,SEO-специалист,Москва,100000.0,,True,RUR,FutureToday
# [112794615, 'SEO-специалист', 'Москва', 100000.0, None, True, 'RUR', 'FutureToday']
# 112338300,Software Engineer Blockchain,Москва,7000.0,7000.0,False,USD,Veretin Solutions Global
# [112338300, 'Software Engineer Blockchain', 'Москва', 7000.0, 7000.0, False, 'USD', 'Veretin Solutions Global']
# 112396810,Старший администратор (девелопмент),Москва,,150000.0,False,RUR,СпецСнабТранс
# [112396810, 'Старший администратор (девелопмент)', 'Москва', None, 150000.0, False, 'RUR', 'СпецСнабТранс']
# 112443054,Менеджер по продукту - Пищевые добавки/БАДы/Косметика (Product Manager),Москва,180000.0,,False,RUR,Деметра
# [112443054, 'Менеджер по продукту - Пищевые добавки/БАДы/Косметика (Product Manager)', 'Москва', 180000.0, None, False, 'RUR', 'Деметра']
# 111348712,IOS Developer,Москва,150000.0,250000.0,False,RUR,Softintermob LLC
# [111348712, 'IOS Developer', 'Москва', 150000.0, 250000.0, False, 'RUR', 'Softintermob LLC']
# 112310314,Java-разработчик,Москва,350000.0,,False,RUR,Рефни
# [112310314, 'Java-разработчик', 'Москва', 350000.0, None, False, 'RUR', 'Рефни']
# 112756328,Инженер службы технической поддержки,Москва,90000.0,110000.0,False,RUR,РПС
# [112756328, 'Инженер службы технической поддержки', 'Москва', 90000.0, 110000.0, False, 'RUR', 'РПС']
# 112783982,Младший системный администратор,Москва,115000.0,,True,RUR,ABCP
# [112783982, 'Младший системный администратор', 'Москва', 115000.0, None, True, 'RUR', 'ABCP']
# 112711495,Vue.js Frontend Middle-Developer на стартап,Москва,800.0,1000.0,False,USD,Чернопятов Давид
# [112711495, 'Vue.js Frontend Middle-Developer на стартап', 'Москва', 800.0, 1000.0, False, 'USD', 'Чернопятов Давид']
# 111476348,Тренер Нутрициолог,Москва,120000.0,,False,RUR,ENHEL GROUP COMPANY
# [111476348, 'Тренер Нутрициолог', 'Москва', 120000.0, None, False, 'RUR', 'ENHEL GROUP COMPANY']
# 111976047,Frontend-разработчик,Москва,250000.0,350000.0,True,RUR,Sapiens solutions
# [111976047, 'Frontend-разработчик', 'Москва', 250000.0, 350000.0, True, 'RUR', 'Sapiens solutions']
# 112357703,Senior Python developer,Москва,350000.0,480000.0,True,RUR,JFoRecruitment
# [112357703, 'Senior Python developer', 'Москва', 350000.0, 480000.0, True, 'RUR', 'JFoRecruitment']
# 112639840,Инженер-разработчик РЭА,Москва,200000.0,,False,RUR,Эколибри
# [112639840, 'Инженер-разработчик РЭА', 'Москва', 200000.0, None, False, 'RUR', 'Эколибри']
# 112207472,React Frontend-разработчик (на верстку креативных сайтов),Москва,80000.0,120000.0,False,RUR,Студия Oxem
# [112207472, 'React Frontend-разработчик (на верстку креативных сайтов)', 'Москва', 80000.0, 120000.0, False, 'RUR', 'Студия Oxem']
# 112612734,Программист-разработчик C#,Москва,140000.0,200000.0,False,RUR,Юниксофт
# [112612734, 'Программист-разработчик C#', 'Москва', 140000.0, 200000.0, False, 'RUR', 'Юниксофт']
# 112722212,Executive Search Recruiter,Москва,170000.0,,False,RUR,Metallurgical company
# [112722212, 'Executive Search Recruiter', 'Москва', 170000.0, None, False, 'RUR', 'Metallurgical company']
# 112772504,"Junior frontend-разработчик в команду технической поддержки / Vue (2 линия, Saas)",Москва,50000.0,75000.0,False,RUR,DIGINETICA
# [112772504, 'Junior frontend-разработчик в команду технической поддержки / Vue (2 линия, Saas)', 'Москва', 50000.0, 75000.0, False, 'RUR', 'DIGINETICA']
# 111341017,BDM (Business Development Manager),Москва,150000.0,,False,RUR,ТОК
# [111341017, 'BDM (Business Development Manager)', 'Москва', 150000.0, None, False, 'RUR', 'ТОК']
# 111351846,Системный администратор (junior),Москва,53000.0,53000.0,False,RUR,Cetera
# [111351846, 'Системный администратор (junior)', 'Москва', 53000.0, 53000.0, False, 'RUR', 'Cetera']
# 112650369,Project manager (web3),Москва,170000.0,,False,RUR,IT Workin
# [112650369, 'Project manager (web3)', 'Москва', 170000.0, None, False, 'RUR', 'IT Workin']
# 112786107,Системный аналитик,Москва,315000.0,400000.0,True,RUR,Selecty
# [112786107, 'Системный аналитик', 'Москва', 315000.0, 400000.0, True, 'RUR', 'Selecty']
# 111355183,Куратор в Английский,Москва,,50000.0,False,RUR,Яндекс Практикум
# [111355183, 'Куратор в Английский', 'Москва', None, 50000.0, False, 'RUR', 'Яндекс Практикум']
# 111845463,PHP-программист,Москва,,200000.0,False,RUR,Инновационная консалтинговая компания РЕАЛАНТ
# [111845463, 'PHP-программист', 'Москва', None, 200000.0, False, 'RUR', 'Инновационная консалтинговая компания РЕАЛАНТ']
# 111404262,Оператор-программист станков с ЧПУ,Москва,150000.0,170000.0,False,RUR,СпецМеталлМастер
# [111404262, 'Оператор-программист станков с ЧПУ', 'Москва', 150000.0, 170000.0, False, 'RUR', 'СпецМеталлМастер']
# 112294699,Senior Javascript / Typescript разработчик,Москва,300000.0,400000.0,False,RUR,Айкрафт
# [112294699, 'Senior Javascript / Typescript разработчик', 'Москва', 300000.0, 400000.0, False, 'RUR', 'Айкрафт']
# 112576157,Программист станков ЧПУ,Москва,200000.0,,False,RUR,Центр Электронной Коммерции
# [112576157, 'Программист станков ЧПУ', 'Москва', 200000.0, None, False, 'RUR', 'Центр Электронной Коммерции']
# 111089779,SMM-менеджер (SMM),Москва,150000.0,,False,RUR,BYTIME
# [111089779, 'SMM-менеджер (SMM)', 'Москва', 150000.0, None, False, 'RUR', 'BYTIME']
# 111960819,Frontend разработчик (Vue),Москва,160000.0,,False,RUR,Комс
# [111960819, 'Frontend разработчик (Vue)', 'Москва', 160000.0, None, False, 'RUR', 'Комс']
# 112445566,Веб-дизайнер Middle,Москва,600.0,,False,USD,Мст
# [112445566, 'Веб-дизайнер Middle', 'Москва', 600.0, None, False, 'USD', 'Мст']

# %%
conn = sqlite3.connect("data/db1.sqlite")
df = pd.read_sql_query("SELECT * FROM vacancies", conn)
conn.close()

df
# Out:
#             id                                              name area_name  \
# 0    112564663        Junior/Middle Frontend разработчик (React)    Москва
# 1    112763765  Junior front-end разработчик (TypeScript, React)    Москва
# 2    112783190                Инженер по охране окружающей среды    Москва
# 3    112746981                              Frontend-разработчик    Москва
# 4    112620411                                 Главный бухгалтер    Москва
# ..         ...                                               ...       ...
# 495  112294699        Senior Javascript / Typescript разработчик    Москва
# 496  112576157                           Программист станков ЧПУ    Москва
# 497  111089779                                SMM-менеджер (SMM)    Москва
# 498  111960819                        Frontend разработчик (Vue)    Москва
# 499  112445566                               Веб-дизайнер Middle    Москва
#
#      salary_from  salary_to  salary_gross salary_currency  \
# 0            NaN    70000.0             0             RUR
# 1       100000.0   180000.0             0             RUR
# 2       200000.0        NaN             0             RUR
# 3        70000.0        NaN             0             RUR
# 4       350000.0   500000.0             0             RUR
# ..           ...        ...           ...             ...
# 495     300000.0   400000.0             0             RUR
# 496     200000.0        NaN             0             RUR
# 497     150000.0        NaN             0             RUR
# 498     160000.0        NaN             0             RUR
# 499        600.0        NaN             0             USD
#
#                    employer_name
# 0                 Hammer Systems
# 1                        Mindbox
# 2               LOTS.Development
# 3                      Aiti Guru
# 4              ФАЙВ ЛЕМОНС ГРУПП
# ..                           ...
# 495                      Айкрафт
# 496  Центр Электронной Коммерции
# 497                       BYTIME
# 498                         Комс
# 499                          Мст
#
# [500 rows x 8 columns]

# %%
def parse_json_object(data: str) -> Dict:
    json_object = {}
    key_value_pattern = (
        r"\"(.*?)\"\s*:\s*(\"[^\"]*\"|\d+(\.\d+)?|true|false|null|\{|\[|\]|\})"
    )
    matches = re.finditer(key_value_pattern, data)
    for match in matches:
        token = match.group(0)
        key = token.split(":")[0].strip().strip('"')
        value = token.split(":")[1].strip().strip('"')
        value = convert_types([value])[0]
        json_object[key] = value
    return json_object


def parse_json_file(file_path: str) -> List[Dict]:
    with open(file_path, "r", encoding="utf-8") as file:
        data = file.read()

    data = data.strip()
    data = data.encode().decode("unicode_escape")
    json_objects = []
    for obj in re.finditer(r"\{.*?\}", data, re.DOTALL):
        json_objects.append(parse_json_object(obj.group(0)))
    return json_objects

# %%
def json_to_sql(
    db_path: str, json_file_path: str, table_name: str, drop_if_exist: bool = False
):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()

    if drop_if_exist:
        cursor.execute(f"DROP TABLE IF EXISTS {table_name}")

    data_list = parse_json_file(json_file_path)

    if not data_list:
        raise ValueError("The JSON file is empty or invalid.")

    columns = ", ".join(data_list[0].keys())
    placeholders = ", ".join(["?"] * len(data_list[0]))
    cursor.execute(f"CREATE TABLE IF NOT EXISTS {table_name} ({columns})")

    for data in data_list:
        values = list(data.values())
        cursor.execute(f"INSERT INTO {table_name} VALUES ({placeholders})", values)

    conn.commit()
    conn.close()

# %%
json_to_sql("data/db2.sqlite", "data/df.json", "vacancies", drop_if_exist=True)
# Out:
# /tmp/ipykernel_412493/1686891791.py:21: DeprecationWarning: invalid escape sequence '\/'
#   data = data.encode().decode("unicode_escape")

# %%
conn = sqlite3.connect("data/db2.sqlite")
df = pd.read_sql_query("SELECT * FROM vacancies", conn)
conn.close()

df
# Out:
#             id                                              name area_name  \
# 0    112564663       Junior\/Middle Frontend разработчик (React)    Москва
# 1    112763765  Junior front-end разработчик (TypeScript, React)    Москва
# 2    112783190                Инженер по охране окружающей среды    Москва
# 3    112746981                              Frontend-разработчик    Москва
# 4    112620411                                 Главный бухгалтер    Москва
# ..         ...                                               ...       ...
# 495  112294699       Senior Javascript \/ Typescript разработчик    Москва
# 496  112576157                           Программист станков ЧПУ    Москва
# 497  111089779                                SMM-менеджер (SMM)    Москва
# 498  111960819                        Frontend разработчик (Vue)    Москва
# 499  112445566                               Веб-дизайнер Middle    Москва
#
#      salary_from  salary_to  salary_gross salary_currency  \
# 0            NaN    70000.0             0             RUR
# 1       100000.0   180000.0             0             RUR
# 2       200000.0        NaN             0             RUR
# 3        70000.0        NaN             0             RUR
# 4       350000.0   500000.0             0             RUR
# ..           ...        ...           ...             ...
# 495     300000.0   400000.0             0             RUR
# 496     200000.0        NaN             0             RUR
# 497     150000.0        NaN             0             RUR
# 498     160000.0        NaN             0             RUR
# 499        600.0        NaN             0             USD
#
#                    employer_name
# 0                 Hammer Systems
# 1                        Mindbox
# 2               LOTS.Development
# 3                      Aiti Guru
# 4              ФАЙВ ЛЕМОНС ГРУПП
# ..                           ...
# 495                      Айкрафт
# 496  Центр Электронной Коммерции
# 497                       BYTIME
# 498                         Комс
# 499                          Мст
#
# [500 rows x 8 columns]

# %% [markdown]
# #### 5. Создать пустую базу db3. Создать три таблицы - вакансии, города, и работодатели. Нормализовать таблицу из 1.1 и разбить ее данные на 3 перечисленные таблицы.

# %%
conn3 = sqlite3.connect("data/db3.sqlite")
c3 = conn3.cursor()

c3.execute(f"DROP TABLE IF EXISTS cities")
c3.execute(f"DROP TABLE IF EXISTS employers")
c3.execute(f"DROP TABLE IF EXISTS vacancies")

c3.execute("""
CREATE TABLE cities (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT UNIQUE
)
""")

c3.execute("""
CREATE TABLE employers (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT UNIQUE
)
""")

c3.execute("""
CREATE TABLE vacancies (
    id TEXT,
    name TEXT,
    city_id INTEGER,
    salary_from REAL,
    salary_to REAL,
    salary_gross BOOLEAN,
    salary_currency TEXT,
    employer_id INTEGER,
    FOREIGN KEY (city_id) REFERENCES cities (id),
    FOREIGN KEY (employer_id) REFERENCES employers (id)
)
""")

cities = df[["area_name"]].drop_duplicates().reset_index(drop=True)
cities["name"] = cities["area_name"]
cities = cities.drop(columns=["area_name"])
cities.to_sql("cities", conn3, if_exists="append", index=False)

employers = df[["employer_name"]].drop_duplicates().reset_index(drop=True)
employers["name"] = employers["employer_name"]
employers = employers.drop(columns=["employer_name"])
employers.to_sql("employers", conn3, if_exists="append", index=False)

df["city_id"] = df["area_name"].apply(
    lambda x: c3.execute("SELECT id FROM cities WHERE name = ?", (x,)).fetchone()[0]
)
df["employer_id"] = df["employer_name"].apply(
    lambda x: c3.execute("SELECT id FROM employers WHERE name = ?", (x,)).fetchone()[0]
)

vacancies = df[
    [
        "id",
        "name",
        "city_id",
        "salary_from",
        "salary_to",
        "salary_gross",
        "salary_currency",
        "employer_id",
    ]
]
vacancies.to_sql("vacancies", conn3, if_exists="append", index=False)

conn3.commit()
conn3.close()

# %% [markdown]
# #### 6. Средствами SQL создать новую колонку очищенной зарплаты в db3, содержащую среднюю зп по полям from и to, пересчитанную в рубли и очищенную от налога (для простоты - 13%)

# %%
conn3 = sqlite3.connect("data/db3.sqlite")
c3 = conn3.cursor()

c3.execute("""
ALTER TABLE vacancies ADD COLUMN real_salary REAL
""")

c3.execute("""
UPDATE vacancies
SET real_salary = (
    CASE
        WHEN salary_currency = 'USD' THEN ((COALESCE(salary_from, 0) + COALESCE(salary_to, 0)) / 2) * 100 * 0.87
        WHEN salary_currency = 'EUR' THEN ((COALESCE(salary_from, 0) + COALESCE(salary_to, 0)) / 2) * 105 * 0.87
        WHEN salary_currency = 'KZT' THEN ((COALESCE(salary_from, 0) + COALESCE(salary_to, 0)) / 2) * 0.2 * 0.87
        ELSE ((COALESCE(salary_from, 0) + COALESCE(salary_to, 0)) / 2) * 0.87
    END
)
""")

conn3.commit()
conn3.close()

# %% [markdown]
# #### 7. По таблицам db3 с помощью JOIN, GROUP BY, HAVING, ORDER BY, вывести по убыванию очищенной зарплаты список вакансий в городах Москва и Ташкент

# %%
conn3 = sqlite3.connect("data/db3.sqlite")
c3 = conn3.cursor()

query = """
SELECT vacancies.id, vacancies.name, cities.name as city_name, vacancies.real_salary
FROM vacancies
JOIN cities ON vacancies.city_id = cities.id
WHERE cities.name IN ('Москва', 'Ташкент')
GROUP BY vacancies.id, vacancies.name, cities.name, vacancies.real_salary
HAVING vacancies.real_salary IS NOT NULL
ORDER BY vacancies.real_salary DESC
"""

result = pd.read_sql_query(query, conn3)
conn3.close()

result
# Out:
#             id                                               name city_name  \
# 0    111939254  TeamLead \/ TeachLead Руководитель отдела разр...    Москва
# 1    112338300                       Software Engineer Blockchain    Москва
# 2    112442788                        Rust Developer (blockchain)    Москва
# 3    112650446                            Lead Frontend Developer    Москва
# 4    112281223                        ML engineer (middle-senior)    Москва
# ..         ...                                                ...       ...
# 491  112185460            Junior\/Junior+php программист (стажёр)    Москва
# 492  112355107                   Программист-разработчик (Junior)    Москва
# 493  112712257                         SMM-менеджер \/ Таргетолог    Москва
# 494  112716298                            Помощник администратора    Москва
# 495  112698776  Unity Developer (Junior+). Разработчик игр на ...    Москва
#
#      real_salary
# 0       870000.0
# 1       609000.0
# 2       587250.0
# 3       565500.0
# 4       522000.0
# ..           ...
# 491      13050.0
# 492      13050.0
# 493      13050.0
# 494      13050.0
# 495       8700.0
#
# [496 rows x 4 columns]

# %% [markdown]
# #### 8. С помощью оконных функций (dense_rank) вывести в каждом городе вакансию с максимальной очищенной зп

# %%
conn3 = sqlite3.connect("data/db3.sqlite")
c3 = conn3.cursor()

query = """
SELECT id, name, city_name, real_salary
FROM (
    SELECT vacancies.id, vacancies.name, cities.name as city_name, vacancies.real_salary,
           DENSE_RANK() OVER (PARTITION BY cities.name ORDER BY vacancies.real_salary DESC) as rank
    FROM vacancies
    JOIN cities ON vacancies.city_id = cities.id
) subquery
WHERE rank = 1
"""

result = pd.read_sql_query(query, conn3)
conn3.close()

result
# Out:
#           id                                               name  \
# 0  112162117                     UX\/UI-дизайнер IT-интерфейсов
# 1  111939254  TeamLead \/ TeachLead Руководитель отдела разр...
# 2  112567699               Программист \/ Разработчик .NET (C#)
# 3  112436052                            Младший тестировщик игр
#
#          city_name  real_salary
# 0       Зеленоград      65250.0
# 1           Москва     870000.0
# 2         Оренбург     139200.0
# 3  Санкт-Петербург      69600.0

# %% [markdown]
# #### 9. С помощью оконных функций (lag, lead, next) для каждой вакансии вывести макс и мин очищенную зп

# %%
conn3 = sqlite3.connect("data/db3.sqlite")
c3 = conn3.cursor()

query = """
SELECT id, name, city_name, real_salary, 
    MAX(real_salary) OVER (PARTITION BY city_name) as max_salary,
    MIN(real_salary) OVER (PARTITION BY city_name) as min_salary,
    LAG(real_salary) OVER (PARTITION BY city_name ORDER BY real_salary) as prev_salary,
    LEAD(real_salary) OVER (PARTITION BY city_name ORDER BY real_salary) as next_salary
FROM (
    SELECT vacancies.id, vacancies.name, cities.name as city_name, vacancies.real_salary
    FROM vacancies
    JOIN cities ON vacancies.city_id = cities.id
) subquery
"""

result = pd.read_sql_query(query, conn3)
conn3.close()

result
# Out:
#             id                                               name  \
# 0    112162117                     UX\/UI-дизайнер IT-интерфейсов
# 1    112698776  Unity Developer (Junior+). Разработчик игр на ...
# 2    112355107                   Программист-разработчик (Junior)
# 3    111971156                              Младший PR-специалист
# 4    112716298                            Помощник администратора
# ..         ...                                                ...
# 495  112338300                       Software Engineer Blockchain
# 496  111939254  TeamLead \/ TeachLead Руководитель отдела разр...
# 497  112567699               Программист \/ Разработчик .NET (C#)
# 498  110758353                                Младший программист
# 499  112436052                            Младший тестировщик игр
#
#            city_name  real_salary  max_salary  min_salary  prev_salary  \
# 0         Зеленоград      65250.0     65250.0     65250.0          NaN
# 1             Москва       8700.0    870000.0      8700.0          NaN
# 2             Москва      13050.0    870000.0      8700.0       8700.0
# 3             Москва      13050.0    870000.0      8700.0      13050.0
# 4             Москва      13050.0    870000.0      8700.0      13050.0
# ..               ...          ...         ...         ...          ...
# 495           Москва     609000.0    870000.0      8700.0     587250.0
# 496           Москва     870000.0    870000.0      8700.0     609000.0
# 497         Оренбург     139200.0    139200.0    139200.0          NaN
# 498  Санкт-Петербург      34800.0     69600.0     34800.0          NaN
# 499  Санкт-Петербург      69600.0     69600.0     34800.0      34800.0
#
#      next_salary
# 0            NaN
# 1        13050.0
# 2        13050.0
# 3        13050.0
# 4        13050.0
# ..           ...
# 495     870000.0
# 496          NaN
# 497          NaN
# 498      69600.0
# 499          NaN
#
# [500 rows x 8 columns]
